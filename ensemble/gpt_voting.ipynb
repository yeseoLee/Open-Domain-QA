# %%
import json
from glob import glob
from collections import Counter, OrderedDict

# %%
# 예측 파일들을 로드합니다.
prediction_files = glob("./results_hard/*.json")

# %%
print(prediction_files)
# Out:
# ['./results_hard\\72.0800_rl_korquad_e1_npassage_e3_es40to5.json', './results_hard\\effie.json', './results_hard\\elise.json']

# %%
from datasets import load_from_disk
import os
import pandas as pd
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)

# Arrow 파일 경로 설정
test_file_path = os.path.join(parent_dir, 'data', 'test_dataset')
test_dataset=load_from_disk(test_file_path)
test_dataset=test_dataset['validation']
test_df=pd.DataFrame(test_dataset)

# %%
# 파일을 읽어와서 predictions 리스트에 저장
def load_predictions(file_paths):
    predictions = []
    for file_path in file_paths:
        with open(file_path, "r", encoding='utf-8') as f:
            predictions.append(json.load(f))
    return predictions

# 각 문항에 대해 3개가 겹치는지, 2개가 겹치는지, 모두 다른지 확인
def check_overlap(predictions):
    all_matching = {}  # 3개가 모두 일치하는 정답
    two_matching = {}  # 2개가 일치하는 정답
    none_matching = {} # 하나도 겹치지 않는 정답

    # 모든 질문에 대해 답변 확인
    for question_id in predictions[0].keys():
        answers = [pred[question_id] for pred in predictions if question_id in pred]
        answer_counts = Counter(answers)

        # 3개의 답변이 모두 동일한 경우
        if len(answer_counts) == 1:
            all_matching[question_id] = answers[0]
        # 2개의 답변이 동일하고, 하나는 다른 경우
        elif len(answer_counts) == 2:
            most_common_answer = answer_counts.most_common(1)[0][0]
            least_common_answer = answer_counts.most_common()[-1][0]
            two_matching[question_id] = [most_common_answer, least_common_answer]
        # 모든 답변이 다른 경우
        else:
            none_matching[question_id] = answers
    
    return all_matching, two_matching, none_matching

# MRC 결과 파일 경로 설정
file_paths = glob("./results_hard/*.json")

# 파일 로드
predictions = load_predictions(file_paths)

# 각 문항에 대해 3개, 2개, 모두 다른 답변을 확인
all_matching, two_matching, none_matching = check_overlap(predictions)

# 질문 매칭을 위해 ID를 key로 한 딕셔너리 생성
id_to_question = dict(zip(test_df['id'], test_df['question']))

# 결과 출력 (질문과 함께 출력)
print("### 3개 모두 겹치는 답변 ###")
for question_id, answer in all_matching.items():
    question = id_to_question.get(question_id, "질문 없음")
    print(f"{question_id}: {answer} ({question})")

print("\n### 2개 겹치는 답변 ###")
for question_id, answers in two_matching.items():
    question = id_to_question.get(question_id, "질문 없음")
    print(f"{question_id}: {answers[0]}, {answers[1]} -----({question})")

print("\n### 모두 다른 답변 ###")
for question_id, answers in none_matching.items():
    question = id_to_question.get(question_id, "질문 없음")
    print(f"{question_id}: {answers} -----({question})")
# Out:
# ### 3개 모두 겹치는 답변 ###
# mrc-1-001113: 냉전 (용병회사의 경기가 좋아진 것은 무엇이 끝난 이후부터인가?)
# mrc-0-002191: 대통령인 빌헬름 미클라스 (돌푸스에게 불특정 기간동안 하원이 잠시 쉬는 것을 건의 받았던 인물은?)
# mrc-0-003951: 뉴질랜드 (마오리언어와 영어, 뉴질랜드 수화를 공식 언어로 사용하는 나라는?)
# mrc-1-001272: 프랑스 (디엔비엔푸 전투에서 보응우옌잡이 상대한 국가는?)
# mrc-1-000993: 유두 (단공류가 일반 포유류와 다르다는 것을 알 수 있는 신체 부위는?)
# mrc-0-001283: 순조 11년(1811) (흉년이 발생하고 곳곳에 난이 일어났던 시기는?)
# mrc-0-004543: 고전도성 철 (급전궤도는 보통 무엇으로 만들어져 있는가?)
# mrc-0-002895: 칼라치 전방 약250km 지점 (제6군이 18일 동안이나 대기해야 했던 장소는?)
# mrc-0-000535: 롭 포드 (누가 시장으로 선출되면서 트랜짓 시티 계획안이 불발되었나?)
# mrc-1-001724: 노스햄프턴 교회 (1차 대각성 운동이 일어나는데 큰 영향을 끼친 설교는 어디서 진행되었는가?)
# mrc-0-001606: 석조 궁륭 (슈파이어 대성당 2차 축조시에 가장 우선순위로 고려했던 천장 건축 방식은?)
# mrc-0-000266: 국민 (통대를 뽑을 수 있었던 주체는 누구인가?)
# mrc-0-000032: 국방부 보고서 (미군이 충원되지 않으면 서울이 전쟁 시작 후 2주만에 함락될 것이라 밝힌 문서는?)
# mrc-0-005215: 입석대(立石臺) (임경업 장군이 도를 닦은 곳으로 알려진 곳은?)
# mrc-0-005407: 숙의 정씨 (화재에서 인종을 구한 공으로 귀인으로 직위가 오른 사람은?)
# mrc-0-003683: 국가인권위원회 (초등학생 일기검사의 인권침해 여부를 판단하는 주체는?)
# mrc-0-002835: 망자 (불보살이 천도할 대상은?)
# mrc-1-001829: 화흡 (조조에게 신고한 사람도 조사해야한다고 한 것은 누구인가?)
# mrc-1-001662: 보신 전쟁 (나카무라 번이 메이지 정부에 굴복하게 된 결투의 이름은 무엇인가요?)
# mrc-0-004007: 신시내티대학교 (밀러허긴스가 법학을 전공한 곳은?)
# mrc-1-000418: 일등바위 (유달산에서 다도해 절경을 볼 수 있는 바위는 무엇인가?)
# mrc-0-004646: 건늠선 (이타미 역이 종착역이었을 때 존재했지만 지진 이후 없어진 것은?)
# mrc-0-004830: 13개 (2001년까지 발견된 해왕성의 총 위성 갯수는?)
# mrc-0-002762: 경복사(景福寺) (보덕이 전주 도달산에 세운 절은?)
# mrc-0-000395: 후쿠도메 시게루 중장 (제2함대의 편에서서 다른 문제를 제기한 인물은?)
# mrc-0-001668: 어머니 (틸의 삼촌댁 방문을 걱정한 인물은?)
# mrc-0-004487: 피터 발스 박사 (코코넛으로 인해 매년 사람이 죽는다는 설화를 인용한 인물은?)
# mrc-0-004413: 호어벨리샤 (체임벌린에 의해 무역부의 회장 자리를 받게 된 사람은?)
# mrc-1-000221: 목제 (철툇자루를 제작하는데 주로 활용된 재료는?)
# mrc-0-002177: 시트로엥 (앙드레-귀스타브 시트로엥이 만든 기업 이름은?)
# mrc-0-003223: 폴 베나세라프 (논문으로 플라톤주의의 허점을 언급한 사람은?)
# mrc-0-004318: 1943년 7월 2일 (여운형이 경성헌병대에서 풀려난 날짜는?)
# mrc-0-002764: 카에데 소이치로 (엔도에게 차키를 돌려주려던 사람은？)
# mrc-0-001725: 스털링 실리펀트 (워렌이 스스로 영화를 제작할 수 있음을 입증하여 승부에서 이긴 상대는 누구인가?)
# mrc-0-004445: 2019년 8월 1일 (지브롤터 내셔널리그의 설립에 영향을 준 개편안이 발표된 시기는?)
# mrc-0-000001: '강연옥' (안영애를 본보기로 만든 <당의 참된 딸>이라는 가극에서 극 중 여자 주연의 이름은?)
# mrc-0-005411: 사비나 (횡령 범죄자 조니를 체포한 요원은 누구인가?)
# mrc-0-003385: 1584년(선조 17년) (동인이 본격적인 세력을 잡은 때는?)
# mrc-1-001555: 소토쿠 고등학교 (미나미 칸토 대회에서 구마가야 고등학교의 1차전 상대 학교는?)
# mrc-0-000988: 노포탑(露砲塔) (19세기 후반의 장갑함에 사용된 화포 형식은?)
# mrc-1-001619: 오야마 이와오 (제2군에 참여한 일본의 유명인사 중 군인 신분으로 참여한 사람은 누구인가?)
# mrc-0-004880: 남미 자브로 (연방군의 캘리포니아 기지보다 더 큰 규모의 기지는 어디에 있는가?)
# mrc-0-003177: 연금 (베토벤이 받았던 후원 요금을 칭하는 단어는 무엇인가요?)
# mrc-1-001523: 니 기븐 (기븐 가의 첫째 아들은 누구인가?)
# mrc-1-001353: 애굽 (여호와가 기드온의 조상을 어디에서 구해냈는가?)
# mrc-0-005278: 근세 (핀란드의 원주민들이 부족사회에서 벗어난 것은 언제인가?)
# mrc-0-000339: 시칠리아 (안드레우치오 디 피에트로를 몰래 지켜보던 인물은 어떤 지역 출신인가요?)
# mrc-0-001183: 러더퍼드 B. 헤이스 (1876년 일반 투표에서 틸던에 패배한 인물은?)
# mrc-1-001155: 광고 (경영을 위해 기관지에 싣기도 하는 것은?)
# mrc-0-000991: 윌리엄 3세 (윌리엄 키드에게 공로장을 준 사람은?)
# mrc-0-005328: 신라 (창원평야 구릉의 평평한 지형에서 발견된 흔적을 통해 성이 언제 지어졌다는 것을 알 수 있는가?)
# mrc-0-002070: 압력 (수증기가 물이 되는 과정에서 가해지는 것은?)
# mrc-0-002453: 다이요 (나가시마에게 감독직을 맡아줄 것을 가장 열렬히 부탁했던 팀은?)
# mrc-0-003274: 필라델피아 (에이미는 서터에게 졸업 이후 어디에서 지내자고 권유하나요?)
# mrc-0-004430: 길거리 불한당 (어머니를 죽음에 이르게 한 것은 아들이 무엇처럼 행동했기 때문인가?)
# mrc-0-003455: 스포츠 신문 (후지무라 감독 퇴진 요구서에 대한 내용을 보도한 언론은?)
# mrc-0-000540: 빌바인 (즈와쓰의 한계 오라력 값보다 필요 오라력 값이 낮은 기체는?)
# mrc-0-000607: 비정상적으로 큰 송곳니 (평행 진화의 결과로 마블고양이가 가지고 있는 것은?)
# mrc-0-003540: 해상 교통, 보급 확보에 충당해야 할 함정과 인력의 부족 (연합 함대가 국지 경비 부대와 해상 호위 부대의 인재 육성을 경시해 일어난 결과는?)
# mrc-1-001466: 1938년 (정주영이 쌀가게 배달원으로 일한 가게를 인수한 해는?)
# mrc-0-004954: 제5중대장 김상흥 대위 (적이 항복 의사를 밝히며 다가오고 있음을 대대장에게 보고한 사람은?)
# mrc-0-004159: 해 (지지)단계 (캐릭터의 다친 장면이 유일하게 나오지 않는 단계는?)
# mrc-0-002445: 콘라트 2세 (잘리어 왕조의 초대황제 이름은?)
# mrc-0-004336: 예루살렘 성전 (야고보가 강압적으로 배교에 관해 설교당했던 장소는?)
# mrc-0-001346: 호해 (진시황이 죽은 이후 황제의 자리에 즉위한 인물은 누구인가?)
# mrc-0-001891: 학업에 집중하기 위해 (2010년 국가대표팀 훈련에 참가한 이다혜가 독일로 돌아가게 된 이유는?)
# mrc-0-000033: 하난야 (웃시야의 정예 전투 병력을 통솔하는 사람은?)
# mrc-0-000201: 블라인드 테스트 (포도주 테이스팅에서는 공평한 평가를 위해 무엇을 진행하기도 하나요?)
# mrc-0-002224: 군대 내 성소수자 권리 정책 (클린턴이 대통령 선거 초반에 내걸었던 정책은?)
# mrc-0-000140: 오코 카무 (베르글룬트가 직장을 그만둔 후 그 자리를 이어받은 사람은?)
# mrc-0-001124: 노화욱 (베트남전 진실위원회 이후에 세워진 단체의 대표는 누구인가요?)
# mrc-0-003870: 도시구 (첫 도입 당시 1013개가 있던 것은?)
# mrc-0-005260: 안드레아스 (전쟁에서 군인들의 삶을 보여주는 주요 등장인물은 누구인가요?)
# mrc-1-000376: 시나위 대금 (산조 대금보다 약 2도 정도 음정이 높은 대금은?)
# mrc-1-000715: 네스토리우스 (예수의 테오토코스에 대해 부정적으로 인식했던 인물은?)
# mrc-0-002747: 믈라카 술탄국 (파라메스와르가 해적의 도움으로 세운 나라는?)
# mrc-1-001341: “가상 연좌시위” (온라인 사이트에 접속하지 못하게 하는 웹상에서의 시위는?)
# mrc-0-003597: 기원전 11년 (로마가 판노니아를 장악한 시기는?)
# mrc-0-003509: 미국 긴축정책 (1980년부터 1985년 사이, 미국달러가 세계 중요 4대 통화에 대해 50% 정도 평가절상된 이유는?)
# mrc-0-001335: 노예를 해방 (헌터가 조지아에서 지시한 사항은 무엇인가?)
# mrc-0-004402: 1995년 (윤락행위등방지법이 전문 개정되었던 해는?)
# mrc-1-000225: 1802년 (베토벤의 귀 상태가 악화된 연도는?)
# mrc-0-003315: 보안 (기존의 공중 네트워크로 중요 문서와 데이터를 전송하는데에 문제가 되었던 것은?)
# mrc-0-004971: 천도교 대종사장(大宗司長) (1919년 정광조의 보직은?)
# mrc-0-004538: 밀 (잉글랜드에서 보리와 함께 가장 많이 경작하는 작물은 무엇인가요?)
# mrc-1-000573: 큰곰자리 운동성군 (미자르는 무엇의 일부인가?)
# mrc-0-005403: 1720년 (스트라디바리가 고령의 조짐을 보이기 시작한 해는?)
# mrc-0-002046: 모겐소 (공격적 현실주의와 대비되는 고전적 현실주의를 설파한 인물은?)
# mrc-0-001943: 디지털 영상 (컴퓨터 시각에서 분할의 대상은?)
# mrc-1-001141: 《후한서》 (삼한총왕설의 근거를 제공한 서적은?)
# mrc-0-002709: 남자의 시체 (리자베타가 꿈 속에서 들었던 장소에 실제로 찾아가 발견한 것은?)
# mrc-0-000313: 케빈 G. 린치 (현직 추밀원사무처장 웨인울터즈의 선임은?)
# mrc-0-003110: 난씨 (진평공이 통치할 때 망해서 사라진 가문은?)
# mrc-0-003155: 스카만드로스 강 (트로이 군사들은 아킬레우스에 의해 어디에서 사망했나요?)
# mrc-1-001242: 볼바라 (세이드를 행하는 여성을 지칭하는 명칭은?)
# mrc-0-004432: 연합국 (세니와 대국 사무관들은 어느 편과 힘을 합치기로 했는가?)
# mrc-0-000755: 이태웅 (공식적인 첫 새천년베이비의 이름은?)
# mrc-1-001802: 호메이니 (레바논 전투에서 헤즈볼라는 누구에 대한 지지를 표명했나요?)
# mrc-0-000016: 스윙 (1930년대 흑인음악으로 백인들의 열렬한 사랑을 받았던 재즈의 한 분야는?)
# mrc-1-000695: 고려 말 (여성의 몸치장에 쓰인 장신구의 위치가 저고리 밑으로 올라오게 된 때는 언제인가?)
# mrc-0-001034: '죄를 범한 자' (공소권이 사라질 경우 무엇에서 벗어나게 되는가?)
# mrc-1-001735: 마리아 팔코네티 (드레이어 감독이 잔 다르크에 비유한 사람은?)
# mrc-1-001179: 쿠페 ("아오테아로아"의 기원에 관한 이야기마다 등장하는 인물은?)
# mrc-1-000521: 종 맨 위 (용통의 위치는?)
# mrc-1-000623: 1866년 (<바다의 일꾼들>이 나온 연도는?)
# mrc-0-003953: 평균비용 (일반비용과 특수비용을 더한 값을 총생산물로 나눴을 때 나오는 값은 무엇인가?)
# mrc-0-002008: HA1 도메인의 18번 코돈 (지금에도 여전히 진화압을 받고 있는 헤마글루티닌 유전자의 한 종류는?)
# mrc-0-002374: 무로마치 막부 (해적중의 활동을 승인한 것은?)
# mrc-1-000086: 이승만 (윤치호가 사촌동생을 통해 만나려고 했던 인물은?)
# mrc-0-004490: 약물 (인쇄사전에서 쉽게 읽히게 하기 위해 사용하는 것은?)
# mrc-1-000780: 강 노인 (미자가 일을 때려친 것은 누구 때문인가?)
# mrc-0-000037: 미켈란젤로 (피렌체파의 대미를 수놓은 사람은?)
# mrc-0-003187: 기암절벽 (고석포, 장군석, 할망바우라는 이름을 가진 바위는 무엇으로 유명한가?)
# mrc-1-000021: 국가안보상 필요할 경우 (법안에서 제재를 취소할 수 있는 권리가 발생하는 경우는 무엇인가?)
# mrc-1-001634: 성경의 요한 계시록 (영화 <제7의 봉인>의 제목의 모티브가 된 것은?)
# mrc-0-004266: 영국 (제1 공수 사단은 어느 나라 부대인가?)
# mrc-0-003249: 노르웨이 (이스다렌의 여인이 중심적으로 스파이 활동을 한 국가는?)
# mrc-0-001728: 약 12,000명 (헨리 5세가 1415년에 프랑스 북쪽을 공격하기 위해 동원한 군사는 몇 명인가?)
# mrc-0-000970: 고천제 (천자등극설'을 대중들에게 확산시킨 행사는?)
# mrc-0-004182: 파시즘 (갖지 못한 국가'가 위기를 극복하기 위해 광폭한 전쟁과 함께 시행한 것은?)
# mrc-0-004626: 웅기탁 (장정기가 들어있는 우산이끼의 가지는?)
# mrc-0-000065: 1,668만 5천 달러 (멕시코 연방 정부는 메탈클래드에게 얼마를 보상하라고 하였나?)
# mrc-0-003016: 신춘문예공모전 (대학원에서 수업을 듣던 시절 소설을 출품하던 곳은 어디었는가?)
# mrc-0-002169: 다케다 한시(武田範之) (이회광이 이용구의 추천으로 원종 고문 자리에 세운 사람은?)
# mrc-0-002771: 보이저 탐사선 (갈릴레오 호 직전에 관측을 진행한 발사체의 이름은?)
# mrc-0-003359: 모자 (사관학교에서 졸업을 할 때 던지는 물건은?)
# mrc-1-000666: 여름철 (노르웨이 노르카프에서는 어느 계절에 백야를 항상 볼 수 있나요?)
# mrc-0-003123: 세르비아군 (1991년에 오브차라를 강제수용소로 변경하여 사용하려 했던 세력은?)
# mrc-0-003614: 복벽 내 (호르몬의 주요 생성장소가 위치한 곳은?)
# mrc-1-000791: 금융위원회 (금산법 제 24조에 의거하여 대통령령이 시행되는 경우 어느 기관의 승인을 받아야 하는가?)
# mrc-1-001485: 에베소 (셰익스피어의 <<실수 연발>>에서 두 쌍의 쌍둥이 형제들이 재회하는 장소는?)
# mrc-0-003425: 3차원 (실제 상황을 이해하려면 몇 차원 상자 속 입자 문제를 풀어야 하나?)
# mrc-0-002676: 아루에 (메구밍에게 자신이 사용하던 안대를 준 사람은?)
# mrc-0-001432: 1887년 (아나톨은 언제부터 작성되었나요?)
# mrc-1-001332: 레이프 세거스탐 (사라스테의 후임은 누구인가?)
# mrc-0-001281: 사법부 (일제강점기 당시 형조와 같은 역할을 한 기관은?)
# mrc-0-003224: 91 cm 구경의 굴절망원경 (버넘이 허빅-아로천체를 찾아냈을 때, 사용한 물건은?)
# mrc-0-000496: 5월 7일 (윤창중이 인턴 직원을 성추행한 것으로 알려진 날짜는?)
# mrc-0-001384: 미술과 (린후이인이 원래 진학하고 싶어했던 과는?)
# mrc-0-003067: 영국 (강요에 의한 개혁이 아니라 긴 기간 동안 의회의 권한을 키운 국가는?)
# mrc-0-004545: 후군 (한중을 공격 시, 군량과 운송이 속한 조조의 부대는?)
# mrc-0-004460: 고문 (주인규는 무엇 때문에 스스로 생을 마감하게 되는가?)
# mrc-0-002975: 엘디아 (프리츠는 어느 나라의 왕인가?)
# mrc-0-004389: 트루먼의 아빠 (트루먼이 탐험을 하지 못하게 크리스토프가 제거한 인물은?)
# mrc-0-005180: Lea et al (1987) (반-베블런 효과가 처음 소개된 곳은?)
# mrc-0-000431: 자기장 (단순 조화 진동자의 진동 주기는 무엇의 세기에 비례하나요?)
# mrc-0-002967: 이라크 (텔 아파르나 키프리를 탈환하기 위해 계획 중인 집단이 소속된 나라는 어디인가?)
# mrc-0-001838: 1916년 (상하이의 북역과 남역 모두를 자유롭게 타기 시작했던 해는?)
# mrc-0-000021: 1862년 (브레킨리지가 루이지애나주 배턴루지를 얻는 데 실패한 해는?)
# mrc-0-004709: 블랙 홀 (매우 센 중력에 의해 빛이 탈출하지 못하는 천체는?)
# mrc-0-003085: 80~90% (국부 제거술로 인한 환관지망생들의 사망률은?)
# mrc-1-000856: 목재와 장작을 실어나르고자 (억스브릿지선이 생긴 이유는?)
# mrc-0-003629: 유성생식 (암컷류가 수중에 생식을 하거나 알주머니를 다른 물체에 붙이는 생식 방법은?)
# mrc-0-005210: 마르크 오버르마르스 (판 호이동크에게 어시스트를 해준 선수는?)
# mrc-0-002685: 1876년 (레오폴 2세가 국제아프리카협회로 부른 민간 지주 회사를 결성한 해는?)
# mrc-0-002389: 유교문화 (대가족제도에서 차별의식을 더욱 강화시켰던 문화는?)
# mrc-0-001366: 신성 로마 제국 (모하치 전투 후 오스만 제국과 헝가리 왕국을 둘로 나눈 나라는?)
# mrc-0-005387: 자동차 폐기장 (임규남이 병원에 입원하는 바람에 해고 당한 직장은?)
# mrc-0-003100: 히브리 백성 (모세가 십계명을 받고 시나이 산에서 내려와 누구를 보고 슬퍼하고 분노했다고 <탈출기>는 전하는가?)
# mrc-0-000898: 이회창 (귀족적인 정치가의 이미지를 탈피하기 위해 노력하였으나 실패한 인물은?)
# mrc-1-000256: 쿠니스 (본인의 일에 진중하게 임했고 많은 것을 연습했지만, 자신의 옷차림에 불만을 제기했던 인물은?)
# mrc-0-004932: 3년 (몇 년간의 전쟁을 통해 '귀방'이라 불리는 이민족이 정벌되었는가?)
# mrc-1-000008: 히틀러의 외투 (슈타우펜베르크는 들 것에 실려나온 사람이 무엇을 덮고 있는 것을 보고 히틀러의 죽음을 단정했나?)
# mrc-0-005465: 쿠파 (버섯왕국의 피치 공주를 납치한 악당 거북의 이름은?)
# mrc-0-003365: '비공식 굿즈' (팬들이 스스로 만드는 상품을 뭐라 하는가?)
# mrc-0-002788: 합작 5원칙 (박헌영이 정부의 역할을 미군정에서 인민위원회로 즉시 넘겨달라고 요구했던 성명은 무엇인가?)
# mrc-1-000582: 소반 (한국에서 음식을 올려놓을때 쓰이는 세간의 이름은 무엇인가요?)
# mrc-0-000345: 주선회 (전효숙이 재판관직 사임으로 민간인이 되었을 때 헌법소장직을 대행 한 사람은?)
# mrc-0-002584: 정규 공간 (우리손은 위상 공간을 거리화하려면 그 공간이 제2 가산 공간임과 더불어 어떤 공간이어야 한다고 증명했나?)
# mrc-0-004928: 하미드 카르자이 (할릴자드 대사와 정치적 이야기를 나눈 아프간 대통령은?)
# mrc-0-004803: 예시 아티드랑 텔렘당 (베니 간츠가 리쿠드당과 같은 노선을 밟겠다는 입장을 표명한 이후, 청백당을 나갔던 인물은?)
# mrc-0-002424: 자인단오-한장군 놀이 (경신자오단오제가 지금의 이름이 되기 직전의 명칭은 무엇이었는가?)
# mrc-0-000205: 제작자 Chris Avellone (게임 발표회에서 제작기간이 부족했다고 한 사람은?)
# mrc-0-002518: 빙하기 세대 (히키코모리가 유독 많아졌던 세대는?)
# mrc-1-001027: 광주지방검찰청 순천지청 (2012년에 공금횡령의 죄목으로 김모씨의 긴급 체포를 진행한 집단은?)
# mrc-0-000122: 종신형 (밀란 루키치는 그의 위법행위로 인해 어떤 형을 받았나?)
# mrc-0-000712: 포토맥군 (북버지니아군이 챈슬러즈빌 전투에서 상대한 것은?)
# mrc-0-003227: 대구 (<굳세어라 금순아>의 작곡가가 실제 피난생활을 했던곳은?)
# mrc-0-002215: 따끄옥루앗 (크리스티앙 드카스를 포로로 잡은 인물은 누구인가?)
# mrc-0-002601: 네덜란드의 1, 2도시 (폐예노르트와 아약스가 "더 클라시커르"에서 맞대결을 할 때 경기가 치뤄지는 곳은?)
# mrc-0-004910: 유럽의 서부 전선 (총 14만 명의 인도인들이 영국 전쟁의 지원을 위해 보내졌던 곳은?)
# mrc-0-002166: 하루 (강희제가 310 마리의 토끼를 사냥하려면 얼마나 걸리는가?)
# mrc-0-003503: 긴급 구호 건설 법령 (공공 사업 법안이 통과되지 못하자 와그너가 내세운 법령은 무엇인가?)
# mrc-0-001845: 조봉암 (모스크바로 가기 위한 여권이 필요한 사람은?)
# mrc-0-000316: 후장식 대포 (금속을 다루는 능력의 진보가 이루어지며 등장한 대포는 무엇인가?)
# mrc-0-003027: 리비우스 (로마의 성벽을 확장한 인물을 기록한 사람은?)
# mrc-0-005283: 감각기에 (반사는 어디에서 온 데이터로 인해 발생하는가?)
# mrc-0-002338: 루피 (도플라밍고가 해군에 체포되기 전에 서로 싸웠으며 그가 현상금 3억 베리를 건 인물은 누구인가?)
# mrc-0-002983: 초등학교 교원 (군자면에서 당 선전으로 활동한 사람들의 직업은?)
# mrc-0-004017: 정원 초과 (합동조사반에 의하면 사고의 원인에는 과적 외에 어떤 것이 있는가?)
# mrc-0-001220: 4점 (양산이씨 종가가 보유한 왕지 중 양산이씨의 시조와 관련한 왕지는 몇 점이 있는가?)
# mrc-0-002746: 아칸바로 (공룡을 닮은 토우는 어디에서 발견되었나요?)
# mrc-0-002285: 열적작용 (주파수가 높은 강한 전자파가 사람의 몸에 닿아 부정적 영향을 일으키는 원리는?)
# mrc-0-001844: 키릴 문자 (10세기 초에 글라골 문자와 그리스 문자를 이용해 새롭게 만들어 낸 문자는?)
# mrc-1-001020: 팔레스타인 (안더스가 폴란드 제2군단을 설립한 나라는?)
# mrc-0-001574: 피오렐로 라과디아 (이탈리아계 미국인들의 민주당 뉴딜 연정 가입으로인해 이득을 본 공화단원은?)
# mrc-1-000155: 1996년 6월 24일 (국민회의 측이 비판한 대통령의 발언은 언제 한 발언이었나?)
# mrc-1-000801: 손가락 (화가 난 스승이 아힘사에게 살인 후 목걸이로 만들어 오라고 한 신체부위는?)
# mrc-0-003959: 스파르타의 장군 길리포스 (아테네가 주도권을 잃어버리는데 영향을 준 인물은?)
# mrc-0-000014: 유대인 (섬 정부가 영국 정부가 지시내리기전에 섬에서 모두 쫓아낸 민족은?)
# mrc-0-000246: 톰 디마르코 (로버트 마틴은 단일 책임 원칙을 알려주기 위해 누구의 책을 참고하였나?)
# mrc-0-001030: 1988년 (금기시된 소재를 다룬 소설이 출간된 해는?)
# mrc-1-001600: 플랑베르주 (하이네스에게 화염의 힘을 받은 인물은 누구인가요?)
# mrc-1-000727: 두 가지 (교황의 자리에 오른 후 보니파시오 3세가 바꾼 것은 몇 개인가?)
# mrc-1-001584: 글래스고 대학교 (제임스 와트와 같은 역사적인 발명가를 배출한 곳은 어디인가요?)
# mrc-1-000387: 정보통신윤리회의 (사이트에 올라오는 콘텐츠를 검열하는 주체는 누구인가?)
# mrc-1-001370: 국제법 (교전 당사자에 대한 전쟁 범죄 심판시 판단 기준이 되는 법은?)
# mrc-1-000621: 간석기(마제석기) (A지구 아랫부분에서 민무늬토기와 더불어 어떤 유물이 발굴되었나?)
# mrc-0-001557: 아테네 (시켈리아 원정을 기획한 국가는?)
# mrc-0-000850: 문장원 (마지막까지 동래권번에 드나든 동래한량꾼은?)
# mrc-0-001149: 오키나와어 (표준어 보급으로 오키나와현에서 고사될 위기에 있는 언어는?)
# mrc-0-000288: 《작가의 일기》 (도스토옙스키를 연구할 때 큰 도움이 됐던 책은?)
# mrc-1-001690: 국립중앙박물관 (인도의 아육왕 계통의 불상의 의복 형식과 유사한 자료를 소장하고 있는 곳은?)
# mrc-0-004363: 파비아 (카를이 교황으로부터 신성 로마 제국 황제관을 부여받은 장소는?)
# mrc-0-000177: 8명 (둠 3: 악마의 부활에서는 최대 몇 명까지 동시에 즐길 수 있나요?)
# mrc-0-002514: API (클라우드 컴퓨팅으로 작동하는 시스템은 무엇을 통해 어플리케이션에 들어갈 수 있나요?)
# mrc-0-001487: 85번 (티칼왕조의 창건자는 몇 번 무덤에 묻혔다고 알려져있나?)
# mrc-0-001938: 코네티컷 소년원 (보닌의 흉터는 어디서 만들어졌을거라 추측되는가?)
# mrc-1-001692: 15개 (유럽에서 두 번째로 큰 국가에는 몇 개의 국립공원이 존재하는가?)
# mrc-0-000574: 1954년 (17도선이 '잠정적인 군사분계선'으로 규정된 연도는?)
# mrc-1-001541: 유대인 (기독교와 메시아에 대한 생각이 다른 사람들은?)
# mrc-1-000550: 마리아의 다섯 가지 기쁨 (종교 개혁 전 영국에서 인기를 끌었던 헌신은?)
# mrc-0-003442: 매개념 (결론에 표시하지 않는 개념은?)
# mrc-0-002868: 1875년 (위트레흐트 육군 군의학교가 폐교된 해는 언제인가요?)
# mrc-0-002848: 케빈 베이컨 (퀵실버(영화)에서 집시를 고가도로에서 추락시킨 사람을 연기한 배우는?)
# mrc-0-001363: 찰스 2세 (1661년 건축 시 제팅기법의 지나친 사용을 제재한 사람은?)
# mrc-0-002282: 마리 알렌 (코페르니쿠스 유해의 진위여부를 밝힌 사람은?)
# mrc-1-001592: 매일 저녁 (오가키로 향하는 아보시 발 도카이도 본선 기차를 운영하는 때는?)
# mrc-1-000013: 요새 (해안포를 정착해 해안을 방어하기 위해 건설한 것은?)
# mrc-0-003170: 1994년 (네덜란드의 모든 이들이 오라녜나사우 훈장을 받을 수 있게 된 건 몇 년인가?)
# mrc-1-001310: 안티트롬빈 (출혈성 천연두 초기와 말기 환자 모두에게 증가하는 물질은?)
# mrc-1-001545: 차가운 점액 (도룡뇽이 수분 증발을 예방하고 몸이 마르지 않도록 내뿜는 것은?)
# mrc-1-001035: 절 (신돈의 어미니는 어느 곳에 소속된 노비인가?)
# mrc-0-000687: 5건 (사건 몇 개를 풀 때 마다 아키이시가 아이템을 주나?)
# mrc-0-003514: 인민의용군 (함세환은 어느 군대에 스스로 입대하여 전투에 참여했나요?)
# mrc-0-004484: 전라남도 지역 (일제의 남한 대토벌 작전은 어느 지역에 대한 압박이었나요?)
# mrc-0-004310: 일본 가도카와 쇼텐 (대원씨아이가 어떤 회사와 계약하여 한국에서 뉴타입을 출간할 수 있었나?)
# mrc-0-004855: 1961년 (베르니이헝 조약이 체결된 해는 언제인가?)
# mrc-0-000328: 사실주의 (시에나의 신비주의에 대비되는 피렌체 미술계의 성향은?)
# mrc-0-002947: 르네상스 양식 (목포근대역사관 본관의 건축 양식은?)
# mrc-0-002720: 하후상 (조비에게 정의를 살려달라고 부탁했다가 사망한 인물은?)
# mrc-0-003413: 스톤페리어 (황금방울새 그림을 유리창의 일부였을거라 추측한 인물은?)
# mrc-1-000320: 1번 ~ 9번 (해동검도의 예도 검법 중에 나한일과 김정호가 직접 만든 검법은?)
# mrc-0-003669: 법무성이 (무슈 두 파리를 선발하는 기관은?)
# mrc-1-001443: 일리노이주 (헨드릭스가 공화당 행정부를 공격했을 당시 어디서 선거 유세를 하던 중이었나?)
# mrc-0-004862: 정통 칼리파(Al-Khalifah Ar-Rashid) (1대부터 4대 칼리파를 통틀어 부른 명칭은?)
# mrc-1-001549: 경추 (그레이가 수술을 받은 것은 어디를 다쳤기 때문인가?)
# mrc-0-002832: 공격력 (월드컵에 출전 한 다른 나라에 비해 대한민국 선수들이 강하지 못한 부분은 무엇인가?)
# mrc-1-000691: 말 (크라테로스를 사망에 이르게 한 동물은?)
# mrc-0-001179: 소프트웨어 엔지니어링 (의존성 주입은 어디에서 쓰이는 기술인가요?)
# mrc-0-004648: 식후 졸림증 (높은 기온과 과식으로 인해 유발되는 증상은 무엇인가?)
# mrc-0-005097: 갈리아인 (카이사르가 브리튼인의 문화와 흡사한 문화를 가지고 있다고 생각한 부족은?)
# mrc-0-002816: 문학 혁명 (셀린 문학의 스타일은 무엇이라 묘사되는가?)
# mrc-0-000895: 줄기군 절지동물 (공하류는 어디로 분류되는 것으로 추측하고 있는가?)
# mrc-0-002436: 오스트리아-헝가리 제국 시대 (헝가리 요리와 오스트리아 요리가 교류한 시기는?)
# mrc-0-002265: 1935년 (와그너법령이 통과된 해는?)
# mrc-0-003068: 시구르드 (파프니르의 피를 마시고 배신당할 것을 알게 된 인물은?)
# mrc-0-001072: 새누리당 (헌재 결정에 대해 적극적으로 동의한 당은?)
# mrc-0-002927: 12척 (후방에 배치된 돈 후안 호세 나바로의 함대의 배는 몇 척인가?)
# mrc-0-000028: 김 대령 (요원들의 마지막 임무 대상은 누구인가?)
# mrc-1-000292: 오티스 소프 (1998년 5월에 리치먼드와 함께 워싱턴 위저즈로 팀을 옮긴 사람은?)
# mrc-0-000499: 극단적인 자전축 경사 (천왕성에서 계절의 변화가 크지 않은 것은 무엇 때문인가?)
# mrc-0-000780: 밖 (수술대 하부에 꿀샘이 존재하면 꽃밥은 어디를 향해 있는가?)
# mrc-1-001635: 배우자 (부부 중 1인이 단독으로 혼인취소소송을 제기하고자 하는 경우 누구를 상대로 소를 제기하여야 하는가?)
# mrc-0-001689: 1671년 (1754년에 철거되었던 시장이 왕실 특허를 재확인받았던 해는?)
# mrc-0-000964: 하리수 (호적을 '남'에서 '여'로 바꾼 인물은?)
# mrc-0-003544: 프랑스 (스페인령 아메리카에서는 누구의 공격에 대응하는 것이 주요한 문제였나?)
# mrc-0-002033: 급진파 (신문 <파시스트 정권,Il Regime Fascista>의 주된 논조는?)
# mrc-1-000189: 공수부대 (롬멜이 어디에 대응하기 위해 나무 기둥과 통나무를 이용하라고 지시했나?)
# mrc-0-003180: 한스 칼 폰 빈터펠트 장군 (아우구스트 빌헬름은 어떤 군지휘관이 모이 전투에서 전사하며 타격을 입게 되나?)
# mrc-1-001214: CP0의 요원 (카쿠와 로브 루치의 현재 신분은?)
# mrc-0-002777: 삼흥 (정치 형태를 홍보하려는 목적으로 류경 스마트폰에 내장된 책의 이름은 무엇인가?)
# mrc-1-001394: 바라아가 (중세 아랍 제국에서 여권과 세금 납부 증명서를 겸용한 서류의 이름은 무엇인가?)
# mrc-1-001716: 1945년 (일본 히로히토 천황이 항복을 선언한 해는?)
# mrc-0-002979: 4칸 (안채와 사랑채 사이에 있는 장소의 앞면은 몇 칸인가요?)
# mrc-0-002536: 리히노브스키 (피아노 즉흥 연주 경연대회에서 베토벤의 스폰서는 누구였는가?)
# mrc-0-002219: 위험한 물질 (곰팡이에 대해 무지했던 사람들은 까망베르 껍질에 대해 어떻게 생각했는가?)
# mrc-0-004690: 리 컬른 (존 크루거가 유일하게 믿는 사람은?)
# mrc-0-002879: 이스라엘 (아랍 연합 공화국은 어느 국가를 상대로 전쟁을 벌였는가?)
# mrc-0-003617: 레온 트로츠키 (볼세비키에 참가해 볼세비키의 군적 역량을 강화시킨 사람은 누구인가?)
# mrc-0-002618: 태황제 (무관학교를 설립한 인물은?)
# mrc-0-001614: 조선 후기 (너비아니에 돼지고기를 사용한 시대는?)
# mrc-0-004674: 테코아쿠 (레르도의 군대가 디아스의 군대에게 대패한 곳은?)
# mrc-0-000393: 고교시절 (박철민이 처음 연기를 시작한 것은 언제인가?)
# mrc-0-000740: 학습자가 정보 통달에 이를 때까지 (학생이 테스트에서 탈락하고 다시 검증을 받는 과정은 언제까지 반복되는가?)
# mrc-0-003904: 1922년 (윤치호가 송도고등보통학교의 네 번째 교장을 맡게 된 해는?)
# mrc-0-005094: 여성 금주 동맹 (투표하기로한 후보 대신 당선되면 시장직을 수행하겠다는 솔터에게 표를 준 단체는?)
# mrc-0-005209: 도쿄의 윤락가 (김옥균이 암살을 피하기 위해 돌아다닌 곳은?)
# mrc-0-003716: 오스트리아 (파아 디브루노 함을 끝까지 공격했던 배는 어느 나라 소속인가요?)
# mrc-0-004081: 세계 최대의 해류 (미시시피 강으로 인해 멕시코 만류가 생겼다는 주장이 힘을 잃은 이유는 멕시코 만류가 무엇으로 알려졌기 때문인가?)
# mrc-0-001180: 1811년 (피아노 협주곡 5번의 첫 공개 초연이 이루어진 해는?)
# mrc-0-003926: 서재필 (윤치호는 성주이씨의 묘소를 누구에게 알려주었는가?)
# mrc-0-001654: 붉은 구슬 (히보코가 용서의 대가로 받은 물건은?)
# mrc-0-000852: 가족의 화합 (부첼라토가 지니는 전통적인 의미는?)
# mrc-0-003331: 200만 달러 (인천상륙장면의 재촬영에 소요된 금액은?)
# mrc-0-004329: 황소 (콘코바르가 알릴과 메브와의 전투에서 분실한 것은?)
# mrc-1-001425: 260억 개 (가트나는 2020년에 사물 인터넷 기술을 사용하는 사물은 몇 개일거라 예측했나?)
# mrc-1-001769: 헝가리 (마가렛의 모친은 어떤 나라의 왕족이었나?)
# mrc-0-002916: 퀸투스 루타티우스 카툴루스 (카틸리나는 누구 덕분에 간통 혐의에서 벗어날 수 있었나요?)
# mrc-0-000435: 젊은이들 (파브르는 그의 글을 통해 누구에게 자연과학에 대한 사랑을 전했는가?)
# mrc-0-000459: 내각회의 (지방총감부 제도를 없애기로 결정한 곳은?)
# mrc-1-000218: 《나뭇잎의 집》 (레이크가 가장 큰 영향을 받았다고 한 작품의 이름은?)
# mrc-1-000181: 강세황 (강현의 아들 이름은?)
# mrc-0-003996: 토우야 (유에에게 마력을 넘겨준 사람은?)
# mrc-0-005410: 오미이마즈 역에서 병결 및 분리를 하는 동안 (쓰루가 방면의 신쾌속 열차가 특급 선더버드 호의 추월을 위해 대기할 때는 언제인가?)
# mrc-0-001793: 플라티니 (베언트 푀어슈터 덕분에 얻은 페널티 킥을 누가 하였는가?)
# mrc-0-001705: 슈베르트 (19세기 가곡이 성행하는 데 큰 역할을 한 인물은?)
# mrc-1-001624: 가즈사 국 (국사가 국내 인부 동원의 권한을 얻는 계기가 된 사건이 일어난 곳은?)
# mrc-1-000694: 연청권 (미종예의 전신은 무엇인가?)
# mrc-0-001425: 중심지 이동설 (고조선의 도읍지와 관련하여 한국 역사학계에서 널리 인정받는 이론은?)
# mrc-1-001516: 가속화 분류기 (분류 작업 중 일정한 시점에 미리 종료함으로써 속도를 올릴 수 있는 것은?)
# mrc-1-000954: 1989년 (제미니 상을 탄 프로그램의 제작 시기는?)
# mrc-0-000096: 2009년 8월 (세종대학교의 기후변화센터는 언제 만들어졌나?)
# mrc-0-003596: 부당한 일요등교 지시 (이대우를 중심으로 모인 학생들은 무엇에 항변하기 위해 시위대를 조직했는가?)
# mrc-0-002651: 영국 (바이츠만은 어떤 나라를 향해 밸푸어 선언을 했나요?)
# mrc-0-001370: 특수목적회사 M2G (타코벨을 한국에 세 번째로 도입한 회사는?)
# mrc-0-002766: 1969년 (기무라의 이론을 기반으로 2명의 학자가 새로운 이론을 발표한 해는?)
# mrc-1-001011: 뷔르츠부르크 대학교 (로타르 마이어가 1853년에 병리학을 공부하던 대학교는 어디였는가?)
# mrc-1-000112: 순치제 (러시아를 견제하기 위해 조선에 군사를 요구한 청나라의 왕은?)
# mrc-1-001436: 앙리 블랑슈 (니콜라 요셉이 벨기에에 돌아가도록 결정적인 영향을 준 기사를 내보낸 사람은?)
# mrc-0-004840: 초나라가 장차 흥성할 것이므로 (태사 백은 환공의 질문에 왜 남쪽이 부적절하다고 답하였는가?)
# mrc-0-001931: 64 군 (스탈린그라드의 소련군 중 사정이 나았던 부대는?)
# mrc-0-004832: 공병우 자판 (특정한 글자에 대해서만 모아치기가 가능한 자판은?)
# mrc-0-000866: 1945년 (쇼와 천황이 맥아더 옆에 직립부동자세로 찍힌 사진이 일반 신문에 실린 해는?)
# mrc-0-000723: 빛 (광배는 부처의 육신에서 나오는 어떠한 것을 하나의 형체로 표현한 것인가?)
# mrc-0-000942: 모터크로스 레이서 (쇼 자마가 부모에 대한 반발을 계기로 가지게 된 장래희망은?)
# mrc-0-004280: 사츠키 (남자친구를 잃은 슬픔에 대해 《Moonlight Shadow》에서 말한 인물은?)
# mrc-1-000518: 아드레날린 (알레르기를 관리하는 계획에는 어떤 호르몬을 투여하는 것도 포함되는가?)
# mrc-1-001582: 1934년 (윤치호가 '질곡의 인디아' 저자를 만났던 해는?)
# mrc-0-002164: 《완전한 죽음》 (<구해줘> 바로 이전에 출간된 책은?)
# mrc-0-001076: 베다는 (보니파시오가 캔터베리 대주교에게 권고 서신을 보낸 적 있다고 말한 사람은?)
# mrc-0-003962: 뉴질랜드 (오스트레일리아의 새로운 개혁정책은 주위 어느 나라에 영향을 주었는가?)
# mrc-1-001301: 대통령 캘빈 쿨리지 (미국 국민들이 일본 대지진에 대한 관심을 갖도록 만드는 데 도움을 준 미국의 인물은?)
# mrc-1-000651: 호림박물관 (대한민국 보물 제 1540호를 보관하는 장소는 어디인가?)
# mrc-0-000845: 오삼계 (1642년 초 이후로 누구의 군대가 유일하게 방패막으로 쓰였나요?)
# mrc-0-002188: 104번 위치의 글루탐산 (삼탄당 인산 이성질화효소 결핍증은 주로 어떤 물질의 돌연변이로 일어나나요?)
# mrc-0-003648: 상대적 손실 가치 (투자 초기 비용보다 매출액이 적더라도 흑자로 판단할 수 있는 기준은?)
# mrc-0-003069: 블루 라인 (첫 해의 기대보다 65% 높은 기수를 받은 노선은?)
# mrc-0-004759: 하이브리드 잉크 배합물 (일부 볼펜에서 잉크가 비교적 빨리 건조되기 위해 사용되는 것은?)
# mrc-1-000412: 미하일린 (2012년 런던 올림픽 결승전에서 리네르에게 패한 사람은 누구인가?)
# mrc-0-001078: 1946년 (에센의 시장에 하이네만이 당선된 해는?)
# mrc-0-000734: 언더우드 박사 (윤치호는 누구의 집에 숨어있었는가?)
# mrc-1-000770: 중동 건설 현장 (오목이 수지에게 청탁한 남편의 일자리 장소는?)
# mrc-0-004187: 승려 (화순 유마사 해련탑은 누구의 무덤인가요?)
# mrc-1-001554: 야기옐론 대학 (코페르니쿠스가 겨울 학기에 등록한 대학은 무슨 대학으로 불리기도 하는가?)
# mrc-0-000062: 전달판 (정란이 방벽에 도달하면 방벽과 탑사이에 내리는 것은?)
# mrc-0-003460: 레기온 (리파리 섬을 공격했을 때 아테네의 군사근거지 위치는 어디였나?)
# mrc-1-000143: 밀양 농잠학교 (진석중이 잠업에 대한 전문기술을 습득한 기관은?)
# mrc-0-001393: 마이클 뉴먼 (서머힐 스쿨 조사관들의 주장이 주관적인 듯이 말한 사람은?)
# mrc-0-001790: 스카버러 타운 센터 (설계자들이 원래 스카버러 도심을 만들려고 했던 곳은?)
# mrc-0-003418: 의사결정권자들 (유심 교수가 오랫동안 인터뷰를 해온 자들은?)
# mrc-0-004465: 와히드 박사 (2008년 당시 몰디브의 부통령은?)
# mrc-0-002840: 화이트워터 사건 (클린턴과 힐러리 여사가 저질렀다는 혐의를 받았던 스캔들은?)
# mrc-1-000227: 동탁의 군대 (양인 전투에서 손견군과 충돌한 부대는?)
# mrc-0-002155: 서울 (과거 우리나라의 전국지는 어디서 출간되었나?)
# mrc-0-001660: 6미터 (오늘날 양치식물이 다 자랐을 때 최대 높이는 몇 미터 미만인가?)
# mrc-0-000913: 탈당 (박기출이 후보지명 되면 조한백, 박재우, 장준하 등이 취하겠다고 한 행동은?)
# mrc-0-004373: 5월 29일 (미네소타주 경찰이 오마르 히메네스를 체포한 날짜는 언제인가요?)
# mrc-1-001229: OekakiBBS (오에카키라는 이름의 모티브는?)
# mrc-0-005342: 소루트비히 (루트비히 2세의 사망 이후, 동프랑크 왕국의 중북부 지방의 땅을 물려받은 인물은?)
# mrc-0-002098: 교황 율리오 2세 (모세상은 누구를 위해 만들어졌었는가?)
# mrc-0-000784: 프랑스 (핵무기 개발건으로 미국과 갈등을 겪다가 통합군사 조직에서 빠진 나라는?)
# mrc-0-004040: 안티오쿠스 (셀레우쿠스에게 왕좌를 계승받은 사람은?)
# mrc-1-001277: 좀비 (헤드크랩의 공격을 받은 레이븐홈의 사람들은 어떤 존재로 변하였는가?)
# mrc-0-000434: 인질이 된 다케치요(이에야스)의 양육을 위해 (게요인이 슨푸로 이사간 이유는?)
# mrc-0-002096: 1947년 (노동운동 단체가 소멸하기 시작한 연도는?)
# mrc-0-000211: 실루엣 (할리퀸이 소설 분위기를 미국풍으로 바꿀 무렵 세운 자회사는?)
# mrc-0-004909: 모술 (쿠틉 앗딘이 이라크에 있는 칼리프 영지를 점거하기 위해 출정을 시작한 지역은?)
# mrc-0-001026: 86 편의 (<어린이와 가정을 위한 이야기>는 원래 몇 편의 이야기로 구성되었나?)
# mrc-0-001864: 보리스 타디치 (2008년에 니콜리치와 대선에서 맞붙어 승리한 인물은?)
# mrc-0-004467: 1994년 (Music Box앨범 이후 다음 앨범의 작업을 시작한 연도는?)
# mrc-0-002636: 1977년 (서울교대를 상징하는 동물을 정한 연도는?)
# mrc-0-002581: 중앙위원회 (어떤 부서가 통일전선조직의 활동을 규제하는가?)
# mrc-0-003040: 일본 (미국이 한국과 더불어 비전략 핵무기를 공유하는 아시아의 파트너 나라는?)
# mrc-0-003558: 연방 정부 (도르발 공항보다 미라벨 공항을 많이 이용할 것이라고 예측했던 기관은?)
# mrc-1-001670: 현무암 화방벽 (대성전의 전면 퇴칸을 제외한 면에 만들어진 것은?)
# mrc-0-004531: 판옥선 (임진왜란에서 일본 수군을 격파한 조선의 배는 무엇인가?)
# mrc-0-003835: 피렌체 ("이탈리아의 예술의 궁전"이라는 별명을 가진 도시는?)
# mrc-0-002683: 1726년 (삼길암 목조관음보살좌상이 조성된 해는?)
# mrc-0-003053: 조선혁명간부학교 (중국 국민당정부의 도움으로 1932년 설립된 교육 기관은?)
# mrc-0-002782: 선조 (서인들은 어떤 왕에게 정여립의 탄핵을 주장하는 상소를 올렸는가?)
# mrc-0-002245: 레드훅 스튜디오 (다키스트 던전을 만든 회사는?)
# mrc-0-002130: 러시아 제국 (프리비슬린스키 크라이는 어느 나라에 소속되어 있었는가?)
# mrc-1-001559: 소방방재센터 (경찰은 어떤 기관의 GPS를 이용하여 오원춘을 체포할 수 있었나요?)
# mrc-0-004672: 존 벨링햄 (퍼시벌에게 앙심을 품고 총을 쏜 인물은?)
# mrc-1-001051: 나르샤(날아 오르다) 선발대회 (19세 이하 남녀가 한국대표로 참가할 수 있는 대회는?)
# mrc-1-000788: 프랑스 (찰스 2세가 국내로 돌아오기 전에 있던 국가는?)
# mrc-0-002530: 안티오코스 3세 (필리포스 5세와 영토를 공유하기로 합의한 사람은?)
# mrc-0-002481: 세 가지 (사용자가 마비노기에서 고를 수 있는 종족은 총 몇 개인가?)
# mrc-0-000283: 비올라 (클래식 연주시 중해금은 어느 악기 옆에 위치해 있는가?)
# mrc-0-003500: 인체의 급소 (백병전은 사람의 신체부위 중 어디를 겨냥하는 무술인가?)
# mrc-1-001669: 대밭골 (금동관음보살입상이 처음 발견된곳으로 추정되는곳은?)
# mrc-0-004372: 대구 (이용문이 육군본부의 장교들과 의견을 나눴던 곳은?)
# mrc-0-000944: 물 (용수로가 운반하는 것은?)
# mrc-0-003528: 어사대부 (대신들이 대홍려 풍야왕을 추천한 직위는?)
# mrc-0-002877: 빌트루디스 (코르비니아노가 비판한 인물은 누구와 혼인하였나요?)
# mrc-0-005447: 석재 (관음정사 존상은 무엇으로 만들어졌나요?)
# mrc-0-004394: 프리드리히 니체 (《그리스 비극 시대의 철학》은 누구의 저서인가?)
# mrc-0-000651: 1967년 (디즈니랜드에서 개인회원을 뽑기 시작한 년도는?)
# mrc-0-002989: 재단 X (타입 2 가이아 메모리을 만든 집단은?)
# mrc-0-001804: 자유당계 인사들 (장면이 정치보복에 반대하는 입장에서 처벌을 원치 않은 대상은?)
# mrc-0-003411: 서스펜디드 게임 (콜드게임 중 어떠한 계기로 인해 잠시 중단된 뒤, 익일에 게임이 진행되는 것은?)
#
# ### 2개 겹치는 답변 ###
# mrc-0-005021: 91년 체제, 대의제도 -----(상류 부르주아의 정치 독점을 불러일으킨 체계는?)
# mrc-1-000163: 구미호, 선종 조사 초상에 연고를 두고 있기 때문 -----(아시노 호가 만들어진 원인은 무엇인가?)
# mrc-0-000439: 리처드 말킨, 점쟁이 -----(클레어에게 오세아닉 815편을 타라고 말한 사람의 이름은?)
# mrc-0-000901: 아라라기 코요미, 오시노 메메 -----(괴수로부터 메구밍을 구해준 사람은 누구인가?)
# mrc-0-001326: ‘자유’지에, 《뉴스피플》 -----(이유립씨가 1970년대 중반에 본인의 글을 기고하기 시작한 곳은?)
# mrc-0-003644: 이탈리아, 백제 -----(콘스탄티누스가 군사 4만 명을 이끌고 침범한 나라는?)
# mrc-0-000049: 게임플레이, 서사 -----(루돌로지스트들이 게임에서 가장 주된 것이라 주장하는 것은?)
# mrc-0-001206: 2007년, 1849년 -----(펌프가 발매된 해는 언제인가?)
# mrc-0-003133: 책, 불법 어업 -----(아델리 펭귄의 목숨에 지장을 주는 사람의 업종은 무엇인가요?)
# mrc-0-001058: 룸비니 동산, 카필라 성 -----(석가모니 부처가 태어난 곳은 어디인가?)
# mrc-0-002361: 독립, 영토 -----(동맹을 맺음으로써 헝가리는 자유를 비롯해 무엇을 잃었나?)
# mrc-0-001086: 라이프치히, 초계면 -----(8천 명의 시민들이 모여 대규모 시위를 벌인 지역은?)
# mrc-0-000624: 영국, 노르웨이 -----(유로니우스를 살해한 용의자가 소속된 밴드의 국적은?)
# mrc-1-001280: 미국 대통령 우드로 윌슨, 미국의 대통령 우드로 윌슨 -----(자신이 고안한 14개조 평화원칙을 국제 사회에 발표하고 싶어한 인물은?)
# mrc-0-000504: 삼국시대, 고려시대 -----(팔과 다리가 밋밋한 형태인 신체표현은 어떤 시기를 반영한 것인가요?)
# mrc-0-003763: 광배(光背)의 뒷면, 불상조성도금사적기(佛像造成塗金事蹟記) -----(불상에 대한 정보가 적혀있는 것은?)
# mrc-0-003896: 마튀랭 박사, 프랭크 맥린 -----(병으로 인해 피렌체의 수많은 사람들이 죽어갔음을 언급한 사람은?)
# mrc-0-003298: 오카다 다케시, 김호 -----(1994년 FIFA 월드컵 당시 대한민국 축구 대표팀의 감독은 누구인가?)
# mrc-0-003628: 공유 필명, 판권관리 -----(선라이즈의 애니메이션 작품 기획부는 야타테 하지메를 무엇으로 사용하는가?)
# mrc-0-000432: 조선건국동맹, 이르쿠츠크파 고려공산당 상하이 지부 -----(여운형이 조동호와 함께 조직한 것은?)
# mrc-0-003364: 아우구스투스 시대, 아우구스투스 시대(기원전 27년 ~ 기원후 14년) -----(단색 배경에 추상적인 디자인을 쓰는 양식이 유행하던 시기는?)
# mrc-0-003670: ‘마루게’ 할아버지, ‘마루게’ -----(최고령 초등학생으로 기네스북에 올라있는 사람은?)
# mrc-0-000386: 야즈데게르드 3세, 호세 1세 -----(628년에 새롭게 왕위에 오른 사람은 누구인가요?)
# mrc-0-004345: 1991년, 2001년 -----(셰이크 무지부르 라흐만의 딸이 처음으로 선거에서 졌던 해는?)
# mrc-0-001470: 볼가 지방, 만주국 무단장 성 무단장 시에 -----(소설 <형제>의 작가가 태어난 지역은?)
# mrc-1-001239: 쉴드 빔, 대형 액정 모니터 -----(무엇이 창 아래에 설치되어 표시기가 한 개 늘어났는가?)
# mrc-0-001940: 경문왕, 신라 경문왕 -----(동화사 석조비로자나불이 제작될 때, 당시 임금은 누구였는가?)
# mrc-0-001241: 환율 부문, 상업 분야 -----(협동 화폐 거래소의 인정은 어느 부문에서 나타나는 변화인가?)
# mrc-1-001457: 도요토미 히데요시, 청나라의 북양대신(北洋大臣) 이홍장 -----(조선역사를 수호하는데 위기를 제공한 사람은?)
# mrc-1-000908: 기생충, 변비 -----(비자나무의 열매는 어떤 증상을 치료하기 위해 쓰이나요?)
# mrc-1-000116: 가이아, 타르타로스 -----(튀폰의 아버지는 누구인가?)
# mrc-0-004669: 교황, 베드로좌 -----(가톨릭 교회에서 주교에게 '최고사제'의 자격을 주는 직함의 이름은?)
# mrc-0-002210: 통인 주기, 조선인민군 -----(아랑을 살해한 사람은?)
# mrc-1-000862: 대막리지 연개소문, 설인귀 -----(당의 군대를 몰살시킨 사람은?)
# mrc-0-000986: 마라도나, 오스마르 -----(전반전이 6분이 지난 후 골을 넣은 선수는?)
# mrc-0-003970: 센리 선, 교토 본선과 센리 선 -----(통근특급이 걸림돌인 노선과 서로 평면교차하는 노선은 어디인가?)
# mrc-0-000304: 1919년 10월 1일, 1919년 1월26일 -----(국경일에 일장기를 달아도 반대하지 않을 것이라는 내용을 담은 윤치호의 일기는 언제 쓰여진 것인가?)
# mrc-1-001025: 티탄즈, 특수부대티탄즈 -----(자미토프가 개혁을 강행하기 위해 설립한 사병 집단은?)
# mrc-0-001374: 1530년, 1305년 -----(성 요한 기사단이 로도스 섬으로 거처를 옮긴 년도는?)
# mrc-0-001783: 자자 빙크스, 나부의 의원 자자 빙크스 -----(팰퍼틴에게 비상시의 권리를 도맡아 달라고 의견을 냈던 인물은?)
# mrc-0-005332: 백제금동대향로, 동탁은잔 -----(날개 앞쪽으로 연꽃을 들고 있는 인면조가 그려진 백제의 유물은 무엇인가?)
# mrc-1-001594: 자유송환, 자동송환 -----(각 측에서 주장된 포로교환 방법 중 선택된 것은?)
# mrc-0-002938: 데이 페소, 찰스 디 페소 -----(티나헤로가 아칸바로의 유적을 날조한 것이라고 주장한 인물은?)
# mrc-0-002936: 소비에트 연방, 붉은 군대 -----(메리의 사촌은 어디에서 영웅으로 활약하기도 했나요?)
# mrc-0-003706: 천공, 6신관 -----(마'를 피하기 위해 살몬 신전을 보낸 곳은?)
# mrc-0-001021: 투사체의 궤적, 보스턴의 폐공장 -----(타격이 시작되는 것은 대상이 어디에 나타날 때인가?)
# mrc-0-003236: 베를린, 프로이센 -----(작센군과 오스트리아군은 함께 어디를 공격할 예정이였나?)
# mrc-0-001379: 퓌르트, 리즈 유나이티드 FC -----(네델란드와의 친선 경기에서 유일하게 골을 넣은 선수의 소속팀은?)
# mrc-0-004927: 풍력이나 조력 발전 등 대체 에너지의 개발, 대체 에너지의 개발 -----(아일랜드의 자원 공급 불안과 지구 온난화에 대한 해결방안은?)
# mrc-0-000576: 알 카포네, 베니토 무솔리니 -----(히틀러의 반란은 누구를 모방한 것인가?)
# mrc-0-002786: 외교부 장관직, 외교부 장관 -----(최초로 공산주의 정당을 제외한 선거 이후 메리가 맡은 직책은?)
# mrc-0-001105: 실존주의, 실존주의 사상 -----(오노에게 영향을 미친 장 폴 사르트르의 철학은?)
# mrc-0-001896: P 시리즈, 스페셜라이즈드의 P 시리즈 -----(산악 자전거 프리 라이드 부문에 출전하는 마틴 소더스트롬이 이용하는 제품은?)
# mrc-0-001887: 고려 중기 이후, 18세기 중후반 -----(부피와 무게감을 나타낸 얼굴이나 짧은 목 등을 통해 알 수 있는 불상의 축조 시기는?)
# mrc-1-001797: 감옥, 뮌헨 발트프리드호프 -----(이경언이 사망한 장소는?)
# mrc-0-002028: 리을설, 리을설(李乙雪, 1921-2015) -----(김일성이 소련인으로서 살고 싶어했다고 말을 한 인물은?)
# mrc-0-003031: 당 태종, 수 양제(煬帝) -----(고구려에 크게 지고 그 전쟁때문에 병이나서 죽은 당나라 왕은?)
# mrc-1-000235: '농지', '농지'(農地) -----(레닌에 의하면 자본주의식 농업 시스템을 통해 일반 시민들이 더 쉽게 사용할 수 있게 된 것은 무엇인가?)
# mrc-0-002716: 《지옥에서 보낸 한 철》, 지에코초 -----(아르튀르가 베르린과의 연애생활을 한 경험을 쓴 시집이름은?)
# mrc-0-003961: 마에노 료타쿠, 스기타 겐파쿠 -----(네덜란드어를 몰랐으나 타펠 아나토미아의 해부도 번역에 참여한 것은 누구인가?)
# mrc-1-001721: 이경희, 조카 윤보선 -----(선생님에게 창씨개명을 하지 않겠다고 한 사람은?)
# mrc-0-004738: 헌법, 일본국헌법 -----(주권재민의 원칙은 어디에 명시되어 있는가?)
# mrc-1-001603: 법관 출신 인사, 사법개혁을 책임질 법관 출신 인사 -----(21대 총선을 겨냥하여 사법개혁을 이끌어갈 수 있다는 것에 뒷받침된 명목은?)
# mrc-0-003356: 언더우드(Underwood)박사, 진주강씨 -----(윤치호의 아내는 누구의 부인을 방문했나?)
# mrc-1-000769: 좌일선의 제1대대, 제1대대 -----(107고지를 처음 함락시킨 부대는?)
# mrc-0-000114: 코드, 코드가 변조되거나 손상되지 않음 -----(코드 서명이 보증하는 대상은?)
# mrc-0-002997: 1922년, 1954년 -----(타누당(TANU)를 설립한 인물이 태어난 해는?)
# mrc-1-000889: 금산전투, 667년의 금산전투 -----(고구려와 당나라 사이에 4대 전투 중 유일하게 다른 해에 일어난 전투는?)
# mrc-1-000267: 3층, 지상 2층 -----(도쇼구 역의 승강장은 몇 층에 있는가?)
# mrc-0-002654: 사운드클라우드, 본인 사운드클라우드 계정 -----(navigation'이 올라온 사이트는?)
# mrc-0-002758: 우크라이나, 잉글랜드 -----(스위스가 월드컵에서 이긴 나라는?)
# mrc-1-001727: 수영공원, 수영사적공원 -----(경상좌도 수군절도사영이 관리했던 곳은?)
# mrc-0-004755: 서울대 터, 장충단공원 -----(공원으로 변화되는 곳은?)
# mrc-0-002525: <<종횡무진 한국경제>>, 종횡무진 한국경제 -----(장하준 교수의 한국경제에 대한 생각에 대해 반론한 김상조 교수의 저서는?)
# mrc-0-001847: 호해, 2세 황제 호해 -----(자신의 사리사욕만 채우며 무능했던 진나라의 황제는?)
# mrc-0-003215: 1773년, 1770년 -----(보스턴 차 사건이 발발한 년도는?)
# mrc-0-001757: 《Nirvana》, Delay 1968 -----(Yoo Doo Right이 수록된 앨범명은?)
# mrc-0-004594: 교육 및 문화 교류를 통해 미국 사람들과 다른 국가 사람들 간의 상호 이해를 높이는 것, 외국인노동자의 정주화 방지 -----(외국인 근로자 고용 등에 대한 법률'의 목적은?)
# mrc-0-001133: 언카스(또는 다운카스, Uncas), 언카스 -----(17세기 피쿼트로부터 독립하여 모하칸족을 만든 사람은?)
# mrc-0-003821: 오스트리아, 잉글랜드 -----(프랑스군은 마렝고에서 어떤 나라의 군대와 마주하였나?)
# mrc-0-001607: 스렝이, 스렝과 -----(누아다가 오른손이 없는 이유는 누구 때문인가?)
# mrc-0-003454: 16세기, 샤를마뉴 황제 (742789 CE) 당시 로마 제국의 쇠퇴 이후 -----(현대 식물원은 언제 오픈되었는가?)
# mrc-0-000206: 2월 혁명, 프랑스 제2공화국을 선포 -----(필리프가 왕실에서 쫒겨난 사건의 단초가 된 역사적 사건은?)
# mrc-0-003043: 경시청 수사1과, 수사1과 -----(시바사키의 이전 소속 부서는?)
# mrc-0-003434: 재산권 박탈, 계획 경제 -----(평등과 복지 사회를 이루기 위해 필요한 것이라는 선전 하에 행해지는 것은?)
# mrc-0-001324: 부산시, 부산 -----(《서편 삼층석탑》은 어느 지역의 유형문화재로 지정되어있나요?)
# mrc-0-002127: 4막 3장이, 4막 3장 -----(맬컴이 맥더프에게 상실에 슬퍼할 줄 알아야 함을 배우는 장은?)
# mrc-0-001438: 금강산 보광암, 봉원사 -----(이보담은 어느 절에서 스님이 되었는가?)
# mrc-0-001415: 상서좌복야(尙書左僕射), 노룡군의 대장 -----(이무훈에게 살해당한 인물의 직책은?)
# mrc-1-000650: 불투명하고 착색된 광물, 광물 -----(조흔색은 무엇을 구별하는데 도움을 주나요?)
# mrc-0-003105: 폭동, 4·19 폭동설’ -----(군부세력들이 어떤 상황을 빌미로 쿠테타를 일으키려고 했나?)
# mrc-0-002170: 《소우기》, 《소우기》(小右記) -----(우치쿠라노 이시메가 작성한 내용이 실린 기록은 무엇인가요?)
# mrc-0-002414: 꼬리부분, 머리와 손목 -----(보디 스타킹에서 봉제되지 않은 부분은?)
# mrc-0-000668: 메란, 돈화현 육정산 고분군 -----(프랑크 왕족들의 무덤이 있는 곳은?)
# mrc-1-001689: 라위스달, 카네츠 신베에 -----(홉베마의 스승은 누구인가요?)
# mrc-0-002493: 미국, 세르비아 -----(쿠챤과 밀로셰비치의 협의에 대해서 작성한 작가의 출신국가는?)
# mrc-0-002092: 소방공무원법, 「소방공무원법」 -----(시도 도지사가 시도 소속 소방공무원을 임용할 수 있도록 개정된 법은?)
# mrc-1-001196: 트리아 터너, 4번째 외야수 -----(2016시즌 당시 테일러는 누구 대신 주전이 되었나?)
# mrc-0-002045: 송병하, 송준길 -----(호연재 김씨의 시증조부는?)
# mrc-0-003645: <밤으로의 긴 여행>, 밤으로의 긴 여행 -----(손턴 와일더 사후, 최고의 명작으로 손꼽히는 작품은 무엇인가?)
# mrc-0-001272: 강물, 왕성 -----(신립이 스스로 목숨을 끊은 곳은?)
# mrc-0-003639: '거대한 탑', '온' -----(단어 '토레혼'의 어근은?)
# mrc-0-001046: 현직 대통령 프랭클린 D. 루스벨트, 프랭클린 D. 루스벨트 -----(총선에서 듀이를 꺾은 사람은?)
# mrc-0-001863: 나스티카, 베다의 권위를 인정하는 가의 여부 -----(베단타 학파와 차르바카파는 무엇을 기준으로 나뉘어졌나요?)
# mrc-0-001123: 레반스라움, 레반스라움을 위한 식민주의 -----(토산물을 착취하는 등과 같은 업무의 명목은?)
# mrc-1-000056: 라크스 클라인, 패트릭 자라 -----(프리덤 건담의 이름을 지은 사람은?)
# mrc-0-001192: 우윤근 원내대표, 박근혜 대통령 -----(통진당을 해산시킨 결정을 인정한다고 직접 말한 인물은?)
# mrc-0-005108: 아도니스, 에로스 -----(진홍빛 장미가 만들어진 원인을 제공한 자는?)
# mrc-1-000713: 드주드주아나의 동굴, 티베트 -----(처음으로 염색된 섬유가 발견되었던 장소는?)
# mrc-0-004970: 한 번, 5.3마리 -----(붉은자이언트날다람쥐 암컷의 일 년 평균 번식 횟수는?)
# mrc-1-000690: 하비 로우마이어, '리카르도 클레멘트' -----(레이가 골트 이후에 사용한 가짜 이름은 무엇인가요?)
# mrc-0-003499: 초음파 가습기, 초음파식 가습기 -----(물방울에 급수대의 이물질이 없는 가습기는?)
# mrc-0-004708: 위장, 땅 속이나 나무 줄기 사이 -----(어버이새가 새끼들의 먹이를 보관하는 곳은?)
# mrc-0-004579: 전라북도 전주, 루이지애나주 센터빌 -----(경서교회를 설립한 사람이 태어난 도시는 어디인가?)
# mrc-0-000255: 인사관리에 대한 통제권, 실권 -----(사장이 부하직원에게 행사할 수 있는 권리는 무엇인가?)
# mrc-0-001539: 목포터미널 인근 도심, 목포 -----(부부가 딸을 차에 태운 곳은?)
# mrc-0-005166: 플로이드가 말을 하고 있으니 괜찮다고, 괜찮다고 -----(행인의 플로이드가 코피난다는 말에 경찰관은 뭐라고 말했는가?)
# mrc-0-000150: 3-3 무승부, 3-3 -----(아만시오가 처음으로 출전한 유럽대항전의 결과는?)
# mrc-0-000760: 공개 프록시, IP 주소 -----(다중 계정 사용자의 판별을 불가능하게 하는 것은?)
# mrc-0-004510: 인체의 치수, 인체의 치수(인체측정학의 측정 기준) -----(인간에게 가장 익숙한 크기의 개념은 무엇인가요?)
# mrc-0-002482: 근원 마그마가 형성되는 기작이 다르기 때문, 근원 마그마가 형성되는 기작 -----(발산형 경계와 수렴형경계의 마그마 점성이 다른 이유는?)
# mrc-1-001729: 수리물리학, 수리 물리학 -----(이론물리학에 비해 수학적인 부분을 더 강조하는 학문은?)
# mrc-0-004371: 미드(Mead), 원세훈 -----(역할을 가장 먼저 구체화 시킨 사람은?)
# mrc-0-002763: 강릉, 개성 -----(신혜왕후가 묻혀있는 지역은?)
# mrc-0-001429: 제노바 공화국, 독일 -----(요안니스 5세의 쿠테타를 지원한 것은 어느 나라인가?)
# mrc-0-004649: 내각, 국가판무관부 -----(히틀러의 권한을 합법적으로 확대시켜준 국가 기관은?)
# mrc-0-004438: 과학적인 의문에 대한 답변을 얻거나 문제에 대한 조사를 하기 위한 목적, 교란 요인을 통제하는 것 -----(연구자들이 설계된 실험실을 이용하는 것은 무엇을 위해서인가?)
# mrc-0-005422: 옥시전 디스트로이어, '옥시전 디스트로이어' -----(세리자와 박사가 숨기려고 한 것은?)
# mrc-0-000394: 김영춘, 김정은 -----(조선인민공화국에서 최고로 높은 직위에 오른 자는?)
# mrc-0-002289: 가덕도, 남해안 연안일대의 요충지 -----(조선수군의 길목을 차단하기 위해 일본군이 설치한 왜성이 위치한 장소는?)
# mrc-0-003038: 에피루스의 주교 에우리아의 요한, 에우리아의 요한 -----(알키온의 주교 자리를 빼앗은 사람은?)
# mrc-0-001682: 사형, 무죄 -----(보닌이 살인 혐의로 체포되어 받은 형벌은?)
# mrc-0-001457: 오스트리아-헝가리 제국, 세르비아 -----(러시아가 동원령을 내린 것은 어느 나라를 견제하기 위해서인가?)
# mrc-0-003755: 권문세족, 무신 -----(정중부의 난 이전 병권을 장악한 집단은?)
# mrc-0-002696: 1948년, 1949년 -----(베이핑-톈진 전투가 시작된 연도는?)
# mrc-0-000564: 1970년, 1835년 -----(여성 작가들이 언제부터 여성 등장인물에 관심을 가지기 시작했나요?)
# mrc-0-004323: 강력범죄 특별수사관, 연극배우 -----(알렉스의 직업은?)
# mrc-0-000664: 벤자민 바커, 벤저민 바커 -----(스위니 토드의 본명은?)
# mrc-0-004392: 뇌 일부, 뇌 -----(모토코의 몸 중에 인공적인 기계장치로 되어 있지 않은 곳은?)
# mrc-0-000162: 스타베크 포트발 크빈네르, 벨기에의 FC 브뤼셀 -----(최재수는 2012년에 어디로 이적했는가?)
# mrc-0-004085: 신라 선덕여왕, R. H. 앨런 -----(맥국이라는 명칭을 알린 사람은?)
# mrc-0-003807: 키홀더, 날카롭게 간 키홀더 -----(오두막의 첫 손님은 어떤 물건을 활용해 자살했는가?)
# mrc-0-004710: 공훈의 보상, 다이라노 다다쓰네의 난 -----(국내무사가 체포 활동에 참가한 것은 무엇 때문인가?)
# mrc-0-005012: 이탈리아 요리, 파스타 -----(미국에서 나폴리식 요리를 의미하는 요리는?)
# mrc-0-003770: 명련사, 명련사이 -----(원래 요괴를 위해 만들었으나 차후 인간들의 신봉도 받게된 시설은?)
# mrc-0-004111: 1924년, 1919년 -----(학생들이 일본인 선생들을 몰아내기 위해 동맹휴학 시위를 일으킨 해는 ?)
# mrc-1-001775: 카르멜 수녀원, 암스테르담 -----(장면이 가족과 떨어져 거처를 옮긴 곳은?)
# mrc-1-000627: 1967년 11월 15일, 9월 26일 -----(도무라 가즈사쿠가 대표로 있던 단체가 공산당과 결별을 선언했던 시기는?)
# mrc-1-001316: 조선무선공학원, 창립기 -----(광운전자공과대학 이전에 사용되던 명칭은 무엇인가요?)
# mrc-1-000977: '나는 참된 보통 선거를 원한다', 나는 참된 보통 선거를 원한다 (我要真普選)' -----(하나를 철거하면 열을 건다' 운동에 사용된 플랜카드의 내용은?)
# mrc-0-003501: 백병계열군, 백병전특화계열의 직업 -----(PK, 수탈을 목적으로 하는 플레이어에게 인기가 많은 직업군은?)
# mrc-1-000841: 사돈인 한진창, 구 대한제국 대신들 -----(윤치호가 고종 독살설을 믿게된 것은 누구 때문인가?)
# mrc-0-005486: 조조, 이각(李傕) 등 -----(헌제는 추격을 당하다 누구에게 도움을 청하였나요?)
# mrc-0-004410: 세르게이 미로노프, 빌헬름 바이틀링 -----(사회민주주의와 민주사회주의를 합친 사상을 가진 집단의 우두머리는 누구인가?)
# mrc-0-001659: 솔레놉신이, 유산 -----(인간에게 불타는 느낌의 아픔을 주는 것은?)
# mrc-0-001251: 공화당원 투표인들 만을 화나게, 공화당원 투표인들 만을 화나게 할 것 -----(듀이는 닉슨을 공천 후보에서 내리는 것이 어떤 결과를 초래할 것이라고 말했는가?)
# mrc-1-000177: 제8조, 제3조 -----(조청상민수륙무역장정중의 8개조중, 장정의 개정에 대한 조항은?)
# mrc-1-001517: 강원도 관찰사인, 강원도도장관 -----(이규완이 강원도에 철도 건설을 제안할 당시 직책은 무엇이었는가?)
# mrc-0-003711: 성철(이영주), 성철 -----(법맥과 전등을 중시하면 스승없이 깨달음을 얻을 수 없다고 주장한 사람은?)
# mrc-0-004335: 뉴욕타임스, 일간 뉴욕타임스 -----(중국 공산당원과 가족의 미국 입국 금지 방안 검토와 관련된 마이크 폼페이오 장관의 입장을 보도한 언론은?)
# mrc-0-003436: 주노 해변, 디에프 해변 -----(제2캐나다기갑여단이 상륙한 곳은?)
# mrc-0-002605: 수수께끼의 콘드률, 콘드률 -----(구립운석을 이루는 물질 중 널리 알려진 것은?)
#
# ### 모두 다른 답변 ###
# mrc-1-000653: ['사만', '사만 행성', '지구'] -----(유령'은 어느 행성에서 지구로 왔는가?)
# mrc-0-000854: ['1916년', '1971년', '2008년'] -----(독일에서 외국 영화를 상영할 수 없게 된 연도는?)
# mrc-0-001235: ['황소자리 성류', '미치류의 화석이 전세계에 걸쳐 발견된다는 것', '화석'] -----(미치류가 해안가를 통해 다른 곳으로 이동했다는 주장을 뒷받침하는 것은?)
# mrc-1-000813: ['태풍 초이완이 마리아나 제도에서 벗어나자', '마리아나 제도', '9월 13일'] -----(태풍 초이완의 경보는 어떤 순간부터 풀렸는가?)
# mrc-0-001699: ['SI 단위계', '미터법', 'SI'] -----(질량을 킬로그램으로 정의하는 단위 규칙은 무엇인가?)
# mrc-0-001884: ['상반신', '하반신', '복잡한 2족 보행기구'] -----(레빌 장군은 무엇이 없었기 때문에 실망했나?)
# mrc-0-003205: ['조선후기', '고려 초경', '조선후기에'] -----(석조지장보살상이 조각되지 않았을 것으로 추정되는 시기는?)
# mrc-0-000359: ['독일', '독일군', '프랑스'] -----(제1차 마른강 전투에서 이긴 국가는?)
# mrc-0-001382: ['이집트', '스페인', '프랑스'] -----(로마의 인력 수급에 중요한 역할을 한 나라는?)
# mrc-0-002723: ['건강 증서', '"건강 증서"', '건강증서'] -----(화물과 배가 시내 가까이에 갈 수 있는지의 여부를 정하는 기준이 된 문서는?)
# mrc-0-001445: ['1918년까지', '1960년 초반 아프리카인들의 독립 이전까지', '1960년 초반 아프리카인들의 독립 이전'] -----(독일의 식민 지배는 언제까지 지속됐는가?)
# mrc-1-000536: ['장래의 시장 상황이 불투명', '양극화', '장래의 시장 상황이 불투명하다면'] -----(안전한 거래를 지지하는 주식 시장 참여자들은 어떤 집단 극화 양상을 보이나요?)
# mrc-0-005293: ['밀리켄역', '케네디역', '유니언역'] -----(1985년 스토우빌선 열차가 스토우빌에서 출발해 여섯 번째로 정차했던 역은?)
# mrc-1-001543: ['머나먼 다리', '밴드 오브 브라더스', '영화 머나먼 다리'] -----(마켓가든 작전을 다룬 작품은?)
# mrc-0-002231: ['악령', '<고골에게 보내는 편지>', '사회적인 희곡'] -----(정치적 코미트를 담고있는 작품은?)
# mrc-0-001961: ['남서풍', '북동풍', '동남풍'] -----(낮에는 어떤 바람이 부는가?)
# mrc-0-004196: ['우주 토끼', '요로감염증', '합병증'] -----(루이가 사망하게 될 원인은 무엇인가?)
# mrc-0-001778: ['1072년', '1045년', '1953년'] -----(고스자쿠 천황이 사망한 연도는?)
# mrc-0-002074: ['3턴', '5턴', '최대 10일'] -----(야전의 전투 제한 시간은?)
# mrc-1-000580: ['장웅', '오토야', '히스토리아가'] -----(키요미와 자신이 아끼는 2명을 지키기 위해 목숨도 아까워 하지 않은 사람은?)
# mrc-0-004245: ['농상무대신', '외무대신', '외무대신과 농상무대신'] -----(이토 히로부미가 정치적 대립관계인 오쿠마 시게노부에게 준 관직은?)
# mrc-0-000500: ['2006년', '2008년', '2009년'] -----(진관희가 짧은 기자 회견을 가진 해는?)
# mrc-1-001071: ['남자아이 빈을 데려다 양자로 삼', '남자아이 빈을 데려다 양자', '남자아이 빈을 데려다 양자로 삼는다.'] -----(좌운검이 도연이 정조의 자손인 것을 아무도 모르게 하기 위해 한 행동은?)
# mrc-1-001269: ['제임스 패닌', '패닌', '제임스 패닌 대령'] -----(에이몬 b. 킹을 파견한 사람은?)
# mrc-1-000870: ['아즈마(東)', '마하프라즈냐파라미타샤스트라(Mahaprajnaparamita\xadsastra)', '이즈마 하치로로'] -----(아즈마의 초기 명칭은?)
# mrc-0-000527: ['순우리말 이름', '보물', '과학의 중요성'] -----(조선박물연구회가 공포하고자 한 것은?)
# mrc-1-000278: ['차벽을 만드는 방법', '정보공개', '사전 구속 영장'] -----(청구취지는 밝히는 방법은?)
# mrc-1-000094: ['구와바라', '구와바라 다케오', '구와바라 다케오(桑原武夫, 교토대 명예교수)'] -----(가와바타가 술 '고도'를 직접 사와서 시음시킨 사람은?)
# mrc-1-000972: ['미노프스키 입자', '염소가스', '미노프스키 입자 산포'] -----(연방군의 레이다를 무력화시킨 화학무기는?)
# mrc-0-000030: ['1643년', "'관왕묘'", '영천 숭렬당'] -----(수사들이 전쟁의 대가로 지은 건물은?)
# mrc-0-001878: ['입석대(立石臺)', '입석대', '문장대'] -----(속리산에서 임경업 장군의 설화가 깃들어있는 곳은 어디인가?)
# mrc-0-003441: ['라트비아', '렌나르트', '인민전선'] -----(에스토니아는 희망을 가졌는가' 를 발표한 인물이 리투아니와 협력한 떄는?)
# mrc-1-000524: ['밀로셰비치', '슬로보단 밀로셰비치', '세르비아의 대통령 슬로보단 밀로셰비치'] -----(인민군이 세르비아를 확장하는 쪽으로 돌아서게 만든 사람은?)
# mrc-1-001426: ['중재위원회를 설치하자고 공식적으로 요청', '수출 규제 해제 요청', '직선기선'] -----(한국이 무시한 일본 측의 주장은?)
# mrc-0-004308: ['폭스바겐 제타', 'Beetles(딱정벌레)', "'Beetles(딱정벌레)'"] -----(폭스바겐이 곤충명을 이름으로 지은 차량은?)
# mrc-0-002991: ['프리큐어들', '사카가미 아유미', '스마일과 스위트 멤버들이'] -----(처음에는 후짱을 반대했지만 마지막에 후짱의 도움을 받은 인물은?)

# %%
from openai import OpenAI

def gpt_select_best_answer(question, answers):
    
    client = OpenAI(
    # This is the default and can be omitted
    api_key=os.environ.get("OPENAI_API_KEY"),
)
    prompt = f"질문: {question}\n\n가능한 답변들: {', '.join(answers)}\n\n위 답변 중에서 가장 적합한 답변을 골라서 출력해. 반드시 저 안에 있어야 하고, 답변만 출력해."
    
    # GPT-3.5 API 호출
    completion = client.chat.completions.create(
        model="chatgpt-4o-latest",  # 사용할 모델
        messages=[{"role": "system", "content": "You are a helpful assistant."},
                  {"role": "user", "content": prompt}],
        max_tokens=100,
        temperature=0.5,
    )
    
    return completion.choices[0].message.content.strip()

# %%
# 2개 겹치는 답변에 대해 GPT로 최종 선택
two_matching_final = {}
print("\n### 2개 겹치는 답변 (GPT 선택) ###")
for question_id, answers in two_matching.items():
    question = id_to_question.get(question_id, "질문 없음")
    final_answer = gpt_select_best_answer(question, answers)
    two_matching_final[question_id] = final_answer
    print(f"{question_id}: {answers} 중 {final_answer} ({question})")

# 모두 다른 답변에 대해 GPT로 최종 선택
none_matching_final = {}
print("\n### 모두 다른 답변 (GPT 선택) ###")
for question_id, answers in none_matching.items():
    question = id_to_question.get(question_id, "질문 없음")
    final_answer = gpt_select_best_answer(question, answers)
    none_matching_final[question_id] = final_answer
    print(f"{question_id}: {answers} 중 {final_answer} ({question})")

# 최종 결과 통합
final_results = all_matching.copy()  # 3개 모두 겹치는 결과 복사
final_results.update(two_matching_final)  # 2개 겹치는 GPT 선택 결과 업데이트
final_results.update(none_matching_final)  # 모두 다른 GPT 선택 결과 업데이트

# 최종 결과를 json 파일로 저장
with open("final_mrc_results(GPT).json", "w", encoding='utf-8') as f:
    json.dump(final_results, f, indent=4, ensure_ascii=False)

print("\n최종 결과가 'final_mrc_results(GPT).json'에 저장되었습니다.")
# Out:
# ### 2개 겹치는 답변 (GPT 선택) ###
# mrc-0-005021: ['91년 체제', '대의제도'] 중 대의제도 (상류 부르주아의 정치 독점을 불러일으킨 체계는?)
# mrc-1-000163: ['구미호', '선종 조사 초상에 연고를 두고 있기 때문'] 중 선종 조사 초상에 연고를 두고 있기 때문 (아시노 호가 만들어진 원인은 무엇인가?)
# mrc-0-000439: ['리처드 말킨', '점쟁이'] 중 리처드 말킨 (클레어에게 오세아닉 815편을 타라고 말한 사람의 이름은?)
# mrc-0-000901: ['아라라기 코요미', '오시노 메메'] 중 아라라기 코요미 (괴수로부터 메구밍을 구해준 사람은 누구인가?)
# mrc-0-001326: ['‘자유’지에', '《뉴스피플》'] 중 ‘자유’지에 (이유립씨가 1970년대 중반에 본인의 글을 기고하기 시작한 곳은?)
# mrc-0-003644: ['이탈리아', '백제'] 중 이탈리아 (콘스탄티누스가 군사 4만 명을 이끌고 침범한 나라는?)
# mrc-0-000049: ['게임플레이', '서사'] 중 게임플레이 (루돌로지스트들이 게임에서 가장 주된 것이라 주장하는 것은?)
# mrc-0-001206: ['2007년', '1849년'] 중 1849년 (펌프가 발매된 해는 언제인가?)
# mrc-0-003133: ['책', '불법 어업'] 중 불법 어업 (아델리 펭귄의 목숨에 지장을 주는 사람의 업종은 무엇인가요?)
# mrc-0-001058: ['룸비니 동산', '카필라 성'] 중 룸비니 동산 (석가모니 부처가 태어난 곳은 어디인가?)
# mrc-0-002361: ['독립', '영토'] 중 독립 (동맹을 맺음으로써 헝가리는 자유를 비롯해 무엇을 잃었나?)
# mrc-0-001086: ['라이프치히', '초계면'] 중 라이프치히 (8천 명의 시민들이 모여 대규모 시위를 벌인 지역은?)
# mrc-0-000624: ['영국', '노르웨이'] 중 노르웨이 (유로니우스를 살해한 용의자가 소속된 밴드의 국적은?)
# mrc-1-001280: ['미국 대통령 우드로 윌슨', '미국의 대통령 우드로 윌슨'] 중 미국 대통령 우드로 윌슨 (자신이 고안한 14개조 평화원칙을 국제 사회에 발표하고 싶어한 인물은?)
# mrc-0-000504: ['삼국시대', '고려시대'] 중 삼국시대 (팔과 다리가 밋밋한 형태인 신체표현은 어떤 시기를 반영한 것인가요?)
# mrc-0-003763: ['광배(光背)의 뒷면', '불상조성도금사적기(佛像造成塗金事蹟記)'] 중 불상조성도금사적기(佛像造成塗金事蹟記) (불상에 대한 정보가 적혀있는 것은?)
# mrc-0-003896: ['마튀랭 박사', '프랭크 맥린'] 중 프랭크 맥린 (병으로 인해 피렌체의 수많은 사람들이 죽어갔음을 언급한 사람은?)
# mrc-0-003298: ['오카다 다케시', '김호'] 중 김호 (1994년 FIFA 월드컵 당시 대한민국 축구 대표팀의 감독은 누구인가?)
# mrc-0-003628: ['공유 필명', '판권관리'] 중 공유 필명 (선라이즈의 애니메이션 작품 기획부는 야타테 하지메를 무엇으로 사용하는가?)
# mrc-0-000432: ['조선건국동맹', '이르쿠츠크파 고려공산당 상하이 지부'] 중 조선건국동맹 (여운형이 조동호와 함께 조직한 것은?)
# mrc-0-003364: ['아우구스투스 시대', '아우구스투스 시대(기원전 27년 ~ 기원후 14년)'] 중 아우구스투스 시대(기원전 27년 ~ 기원후 14년) (단색 배경에 추상적인 디자인을 쓰는 양식이 유행하던 시기는?)
# mrc-0-003670: ['‘마루게’ 할아버지', '‘마루게’'] 중 마루게 (최고령 초등학생으로 기네스북에 올라있는 사람은?)
# mrc-0-000386: ['야즈데게르드 3세', '호세 1세'] 중 야즈데게르드 3세 (628년에 새롭게 왕위에 오른 사람은 누구인가요?)
# mrc-0-004345: ['1991년', '2001년'] 중 2001년 (셰이크 무지부르 라흐만의 딸이 처음으로 선거에서 졌던 해는?)
# mrc-0-001470: ['볼가 지방', '만주국 무단장 성 무단장 시에'] 중 만주국 무단장 성 무단장 시에 (소설 <형제>의 작가가 태어난 지역은?)
# mrc-1-001239: ['쉴드 빔', '대형 액정 모니터'] 중 쉴드 빔 (무엇이 창 아래에 설치되어 표시기가 한 개 늘어났는가?)
# mrc-0-001940: ['경문왕', '신라 경문왕'] 중 신라 경문왕 (동화사 석조비로자나불이 제작될 때, 당시 임금은 누구였는가?)
# mrc-0-001241: ['환율 부문', '상업 분야'] 중 상업 분야 (협동 화폐 거래소의 인정은 어느 부문에서 나타나는 변화인가?)
# mrc-1-001457: ['도요토미 히데요시', '청나라의 북양대신(北洋大臣) 이홍장'] 중 도요토미 히데요시 (조선역사를 수호하는데 위기를 제공한 사람은?)
# mrc-1-000908: ['기생충', '변비'] 중 기생충 (비자나무의 열매는 어떤 증상을 치료하기 위해 쓰이나요?)
# mrc-1-000116: ['가이아', '타르타로스'] 중 타르타로스 (튀폰의 아버지는 누구인가?)
# mrc-0-004669: ['교황', '베드로좌'] 중 베드로좌 (가톨릭 교회에서 주교에게 '최고사제'의 자격을 주는 직함의 이름은?)
# mrc-0-002210: ['통인 주기', '조선인민군'] 중 통인 주기 (아랑을 살해한 사람은?)
# mrc-1-000862: ['대막리지 연개소문', '설인귀'] 중 설인귀 (당의 군대를 몰살시킨 사람은?)
# mrc-0-000986: ['마라도나', '오스마르'] 중 오스마르 (전반전이 6분이 지난 후 골을 넣은 선수는?)
# mrc-0-003970: ['센리 선', '교토 본선과 센리 선'] 중 교토 본선과 센리 선 (통근특급이 걸림돌인 노선과 서로 평면교차하는 노선은 어디인가?)
# mrc-0-000304: ['1919년 10월 1일', '1919년 1월26일'] 중 1919년 10월 1일 (국경일에 일장기를 달아도 반대하지 않을 것이라는 내용을 담은 윤치호의 일기는 언제 쓰여진 것인가?)
# mrc-1-001025: ['티탄즈', '특수부대티탄즈'] 중 티탄즈 (자미토프가 개혁을 강행하기 위해 설립한 사병 집단은?)
# mrc-0-001374: ['1530년', '1305년'] 중 1305년 (성 요한 기사단이 로도스 섬으로 거처를 옮긴 년도는?)
# mrc-0-001783: ['자자 빙크스', '나부의 의원 자자 빙크스'] 중 나부의 의원 자자 빙크스 (팰퍼틴에게 비상시의 권리를 도맡아 달라고 의견을 냈던 인물은?)
# mrc-0-005332: ['백제금동대향로', '동탁은잔'] 중 백제금동대향로 (날개 앞쪽으로 연꽃을 들고 있는 인면조가 그려진 백제의 유물은 무엇인가?)
# mrc-1-001594: ['자유송환', '자동송환'] 중 자유송환 (각 측에서 주장된 포로교환 방법 중 선택된 것은?)
# mrc-0-002938: ['데이 페소', '찰스 디 페소'] 중 찰스 디 페소 (티나헤로가 아칸바로의 유적을 날조한 것이라고 주장한 인물은?)
# mrc-0-002936: ['소비에트 연방', '붉은 군대'] 중 붉은 군대 (메리의 사촌은 어디에서 영웅으로 활약하기도 했나요?)
# mrc-0-003706: ['천공', '6신관'] 중 천공 (마'를 피하기 위해 살몬 신전을 보낸 곳은?)
# mrc-0-001021: ['투사체의 궤적', '보스턴의 폐공장'] 중 투사체의 궤적 (타격이 시작되는 것은 대상이 어디에 나타날 때인가?)
# mrc-0-003236: ['베를린', '프로이센'] 중 베를린 (작센군과 오스트리아군은 함께 어디를 공격할 예정이였나?)
# mrc-0-001379: ['퓌르트', '리즈 유나이티드 FC'] 중 리즈 유나이티드 FC (네델란드와의 친선 경기에서 유일하게 골을 넣은 선수의 소속팀은?)
# mrc-0-004927: ['풍력이나 조력 발전 등 대체 에너지의 개발', '대체 에너지의 개발'] 중 풍력이나 조력 발전 등 대체 에너지의 개발 (아일랜드의 자원 공급 불안과 지구 온난화에 대한 해결방안은?)
# mrc-0-000576: ['알 카포네', '베니토 무솔리니'] 중 베니토 무솔리니 (히틀러의 반란은 누구를 모방한 것인가?)
# mrc-0-002786: ['외교부 장관직', '외교부 장관'] 중 외교부 장관 (최초로 공산주의 정당을 제외한 선거 이후 메리가 맡은 직책은?)
# mrc-0-001105: ['실존주의', '실존주의 사상'] 중 실존주의 (오노에게 영향을 미친 장 폴 사르트르의 철학은?)
# mrc-0-001896: ['P 시리즈', '스페셜라이즈드의 P 시리즈'] 중 스페셜라이즈드의 P 시리즈 (산악 자전거 프리 라이드 부문에 출전하는 마틴 소더스트롬이 이용하는 제품은?)
# mrc-0-001887: ['고려 중기 이후', '18세기 중후반'] 중 고려 중기 이후 (부피와 무게감을 나타낸 얼굴이나 짧은 목 등을 통해 알 수 있는 불상의 축조 시기는?)
# mrc-1-001797: ['감옥', '뮌헨 발트프리드호프'] 중 뮌헨 발트프리드호프 (이경언이 사망한 장소는?)
# mrc-0-002028: ['리을설', '리을설(李乙雪, 1921-2015)'] 중 리을설(李乙雪, 1921-2015) (김일성이 소련인으로서 살고 싶어했다고 말을 한 인물은?)
# mrc-0-003031: ['당 태종', '수 양제(煬帝)'] 중 당 태종 (고구려에 크게 지고 그 전쟁때문에 병이나서 죽은 당나라 왕은?)
# mrc-1-000235: ["'농지'", "'농지'(農地)"] 중 '농지' (레닌에 의하면 자본주의식 농업 시스템을 통해 일반 시민들이 더 쉽게 사용할 수 있게 된 것은 무엇인가?)
# mrc-0-002716: ['《지옥에서 보낸 한 철》', '지에코초'] 중 《지옥에서 보낸 한 철》 (아르튀르가 베르린과의 연애생활을 한 경험을 쓴 시집이름은?)
# mrc-0-003961: ['마에노 료타쿠', '스기타 겐파쿠'] 중 스기타 겐파쿠 (네덜란드어를 몰랐으나 타펠 아나토미아의 해부도 번역에 참여한 것은 누구인가?)
# mrc-1-001721: ['이경희', '조카 윤보선'] 중 조카 윤보선 (선생님에게 창씨개명을 하지 않겠다고 한 사람은?)
# mrc-0-004738: ['헌법', '일본국헌법'] 중 헌법 (주권재민의 원칙은 어디에 명시되어 있는가?)
# mrc-1-001603: ['법관 출신 인사', '사법개혁을 책임질 법관 출신 인사'] 중 사법개혁을 책임질 법관 출신 인사 (21대 총선을 겨냥하여 사법개혁을 이끌어갈 수 있다는 것에 뒷받침된 명목은?)
# mrc-0-003356: ['언더우드(Underwood)박사', '진주강씨'] 중 언더우드(Underwood)박사 (윤치호의 아내는 누구의 부인을 방문했나?)
# mrc-1-000769: ['좌일선의 제1대대', '제1대대'] 중 제1대대 (107고지를 처음 함락시킨 부대는?)
# mrc-0-000114: ['코드', '코드가 변조되거나 손상되지 않음'] 중 코드가 변조되거나 손상되지 않음 (코드 서명이 보증하는 대상은?)
# mrc-0-002997: ['1922년', '1954년'] 중 1922년 (타누당(TANU)를 설립한 인물이 태어난 해는?)
# mrc-1-000889: ['금산전투', '667년의 금산전투'] 중 667년의 금산전투 (고구려와 당나라 사이에 4대 전투 중 유일하게 다른 해에 일어난 전투는?)
# mrc-1-000267: ['3층', '지상 2층'] 중 지상 2층 (도쇼구 역의 승강장은 몇 층에 있는가?)
# mrc-0-002654: ['사운드클라우드', '본인 사운드클라우드 계정'] 중 사운드클라우드 (navigation'이 올라온 사이트는?)
# mrc-0-002758: ['우크라이나', '잉글랜드'] 중 잉글랜드 (스위스가 월드컵에서 이긴 나라는?)
# mrc-1-001727: ['수영공원', '수영사적공원'] 중 수영사적공원 (경상좌도 수군절도사영이 관리했던 곳은?)
# mrc-0-004755: ['서울대 터', '장충단공원'] 중 장충단공원 (공원으로 변화되는 곳은?)
# mrc-0-002525: ['<<종횡무진 한국경제>>', '종횡무진 한국경제'] 중 종횡무진 한국경제 (장하준 교수의 한국경제에 대한 생각에 대해 반론한 김상조 교수의 저서는?)
# mrc-0-001847: ['호해', '2세 황제 호해'] 중 2세 황제 호해 (자신의 사리사욕만 채우며 무능했던 진나라의 황제는?)
# mrc-0-003215: ['1773년', '1770년'] 중 1773년 (보스턴 차 사건이 발발한 년도는?)
# mrc-0-001757: ['《Nirvana》', 'Delay 1968'] 중 Delay 1968 (Yoo Doo Right이 수록된 앨범명은?)
# mrc-0-004594: ['교육 및 문화 교류를 통해 미국 사람들과 다른 국가 사람들 간의 상호 이해를 높이는 것', '외국인노동자의 정주화 방지'] 중 외국인노동자의 정주화 방지 (외국인 근로자 고용 등에 대한 법률'의 목적은?)
# mrc-0-001133: ['언카스(또는 다운카스, Uncas)', '언카스'] 중 언카스 (17세기 피쿼트로부터 독립하여 모하칸족을 만든 사람은?)
# mrc-0-003821: ['오스트리아', '잉글랜드'] 중 오스트리아 (프랑스군은 마렝고에서 어떤 나라의 군대와 마주하였나?)
# mrc-0-001607: ['스렝이', '스렝과'] 중 스렝 (누아다가 오른손이 없는 이유는 누구 때문인가?)
# mrc-0-003454: ['16세기', '샤를마뉴 황제 (742789 CE) 당시 로마 제국의 쇠퇴 이후'] 중 16세기 (현대 식물원은 언제 오픈되었는가?)
# mrc-0-000206: ['2월 혁명', '프랑스 제2공화국을 선포'] 중 2월 혁명 (필리프가 왕실에서 쫒겨난 사건의 단초가 된 역사적 사건은?)
# mrc-0-003043: ['경시청 수사1과', '수사1과'] 중 수사1과 (시바사키의 이전 소속 부서는?)
# mrc-0-003434: ['재산권 박탈', '계획 경제'] 중 재산권 박탈 (평등과 복지 사회를 이루기 위해 필요한 것이라는 선전 하에 행해지는 것은?)
# mrc-0-001324: ['부산시', '부산'] 중 부산 (《서편 삼층석탑》은 어느 지역의 유형문화재로 지정되어있나요?)
# mrc-0-002127: ['4막 3장이', '4막 3장'] 중 4막 3장 (맬컴이 맥더프에게 상실에 슬퍼할 줄 알아야 함을 배우는 장은?)
# mrc-0-001438: ['금강산 보광암', '봉원사'] 중 봉원사 (이보담은 어느 절에서 스님이 되었는가?)
# mrc-0-001415: ['상서좌복야(尙書左僕射)', '노룡군의 대장'] 중 상서좌복야(尙書左僕射) (이무훈에게 살해당한 인물의 직책은?)
# mrc-1-000650: ['불투명하고 착색된 광물', '광물'] 중 광물 (조흔색은 무엇을 구별하는데 도움을 주나요?)
# mrc-0-003105: ['폭동', '4·19 폭동설’'] 중 4·19 폭동설 (군부세력들이 어떤 상황을 빌미로 쿠테타를 일으키려고 했나?)
# mrc-0-002170: ['《소우기》', '《소우기》(小右記)'] 중 《소우기》(小右記) (우치쿠라노 이시메가 작성한 내용이 실린 기록은 무엇인가요?)
# mrc-0-002414: ['꼬리부분', '머리와 손목'] 중 머리와 손목 (보디 스타킹에서 봉제되지 않은 부분은?)
# mrc-0-000668: ['메란', '돈화현 육정산 고분군'] 중 메란 (프랑크 왕족들의 무덤이 있는 곳은?)
# mrc-1-001689: ['라위스달', '카네츠 신베에'] 중 라위스달 (홉베마의 스승은 누구인가요?)
# mrc-0-002493: ['미국', '세르비아'] 중 세르비아 (쿠챤과 밀로셰비치의 협의에 대해서 작성한 작가의 출신국가는?)
# mrc-0-002092: ['소방공무원법', '「소방공무원법」'] 중 소방공무원법 (시도 도지사가 시도 소속 소방공무원을 임용할 수 있도록 개정된 법은?)
# mrc-1-001196: ['트리아 터너', '4번째 외야수'] 중 트리아 터너 (2016시즌 당시 테일러는 누구 대신 주전이 되었나?)
# mrc-0-002045: ['송병하', '송준길'] 중 송준길 (호연재 김씨의 시증조부는?)
# mrc-0-003645: ['<밤으로의 긴 여행>', '밤으로의 긴 여행'] 중 밤으로의 긴 여행 (손턴 와일더 사후, 최고의 명작으로 손꼽히는 작품은 무엇인가?)
# mrc-0-001272: ['강물', '왕성'] 중 강물 (신립이 스스로 목숨을 끊은 곳은?)
# mrc-0-003639: ["'거대한 탑'", "'온'"] 중 '거대한 탑' (단어 '토레혼'의 어근은?)
# mrc-0-001046: ['현직 대통령 프랭클린 D. 루스벨트', '프랭클린 D. 루스벨트'] 중 프랭클린 D. 루스벨트 (총선에서 듀이를 꺾은 사람은?)
# mrc-0-001863: ['나스티카', '베다의 권위를 인정하는 가의 여부'] 중 베다의 권위를 인정하는 가의 여부 (베단타 학파와 차르바카파는 무엇을 기준으로 나뉘어졌나요?)
# mrc-0-001123: ['레반스라움', '레반스라움을 위한 식민주의'] 중 레반스라움을 위한 식민주의 (토산물을 착취하는 등과 같은 업무의 명목은?)
# mrc-1-000056: ['라크스 클라인', '패트릭 자라'] 중 라크스 클라인 (프리덤 건담의 이름을 지은 사람은?)
# mrc-0-001192: ['우윤근 원내대표', '박근혜 대통령'] 중 박근혜 대통령 (통진당을 해산시킨 결정을 인정한다고 직접 말한 인물은?)
# mrc-0-005108: ['아도니스', '에로스'] 중 아도니스 (진홍빛 장미가 만들어진 원인을 제공한 자는?)
# mrc-1-000713: ['드주드주아나의 동굴', '티베트'] 중 드주드주아나의 동굴 (처음으로 염색된 섬유가 발견되었던 장소는?)
# mrc-0-004970: ['한 번', '5.3마리'] 중 한 번 (붉은자이언트날다람쥐 암컷의 일 년 평균 번식 횟수는?)
# mrc-1-000690: ['하비 로우마이어', "'리카르도 클레멘트'"] 중 하비 로우마이어 (레이가 골트 이후에 사용한 가짜 이름은 무엇인가요?)
# mrc-0-003499: ['초음파 가습기', '초음파식 가습기'] 중 초음파식 가습기 (물방울에 급수대의 이물질이 없는 가습기는?)
# mrc-0-004708: ['위장', '땅 속이나 나무 줄기 사이'] 중 위장 (어버이새가 새끼들의 먹이를 보관하는 곳은?)
# mrc-0-004579: ['전라북도 전주', '루이지애나주 센터빌'] 중 전라북도 전주 (경서교회를 설립한 사람이 태어난 도시는 어디인가?)
# mrc-0-000255: ['인사관리에 대한 통제권', '실권'] 중 인사관리에 대한 통제권 (사장이 부하직원에게 행사할 수 있는 권리는 무엇인가?)
# mrc-0-001539: ['목포터미널 인근 도심', '목포'] 중 목포터미널 인근 도심 (부부가 딸을 차에 태운 곳은?)
# mrc-0-005166: ['플로이드가 말을 하고 있으니 괜찮다고', '괜찮다고'] 중 플로이드가 말을 하고 있으니 괜찮다고 (행인의 플로이드가 코피난다는 말에 경찰관은 뭐라고 말했는가?)
# mrc-0-000150: ['3-3 무승부', '3-3'] 중 3-3 (아만시오가 처음으로 출전한 유럽대항전의 결과는?)
# mrc-0-000760: ['공개 프록시', 'IP 주소'] 중 공개 프록시 (다중 계정 사용자의 판별을 불가능하게 하는 것은?)
# mrc-0-004510: ['인체의 치수', '인체의 치수(인체측정학의 측정 기준)'] 중 인체의 치수(인체측정학의 측정 기준) (인간에게 가장 익숙한 크기의 개념은 무엇인가요?)
# mrc-0-002482: ['근원 마그마가 형성되는 기작이 다르기 때문', '근원 마그마가 형성되는 기작'] 중 근원 마그마가 형성되는 기작이 다르기 때문 (발산형 경계와 수렴형경계의 마그마 점성이 다른 이유는?)
# mrc-1-001729: ['수리물리학', '수리 물리학'] 중 수리물리학 (이론물리학에 비해 수학적인 부분을 더 강조하는 학문은?)
# mrc-0-004371: ['미드(Mead)', '원세훈'] 중 미드(Mead) (역할을 가장 먼저 구체화 시킨 사람은?)
# mrc-0-002763: ['강릉', '개성'] 중 강릉 (신혜왕후가 묻혀있는 지역은?)
# mrc-0-001429: ['제노바 공화국', '독일'] 중 제노바 공화국 (요안니스 5세의 쿠테타를 지원한 것은 어느 나라인가?)
# mrc-0-004649: ['내각', '국가판무관부'] 중 내각 (히틀러의 권한을 합법적으로 확대시켜준 국가 기관은?)
# mrc-0-004438: ['과학적인 의문에 대한 답변을 얻거나 문제에 대한 조사를 하기 위한 목적', '교란 요인을 통제하는 것'] 중 과학적인 의문에 대한 답변을 얻거나 문제에 대한 조사를 하기 위한 목적 (연구자들이 설계된 실험실을 이용하는 것은 무엇을 위해서인가?)
# mrc-0-005422: ['옥시전 디스트로이어', "'옥시전 디스트로이어'"] 중 옥시전 디스트로이어 (세리자와 박사가 숨기려고 한 것은?)
# mrc-0-000394: ['김영춘', '김정은'] 중 김정은 (조선인민공화국에서 최고로 높은 직위에 오른 자는?)
# mrc-0-002289: ['가덕도', '남해안 연안일대의 요충지'] 중 남해안 연안일대의 요충지 (조선수군의 길목을 차단하기 위해 일본군이 설치한 왜성이 위치한 장소는?)
# mrc-0-003038: ['에피루스의 주교 에우리아의 요한', '에우리아의 요한'] 중 에우리아의 요한 (알키온의 주교 자리를 빼앗은 사람은?)
# mrc-0-001682: ['사형', '무죄'] 중 사형 (보닌이 살인 혐의로 체포되어 받은 형벌은?)
# mrc-0-001457: ['오스트리아-헝가리 제국', '세르비아'] 중 세르비아 (러시아가 동원령을 내린 것은 어느 나라를 견제하기 위해서인가?)
# mrc-0-003755: ['권문세족', '무신'] 중 무신 (정중부의 난 이전 병권을 장악한 집단은?)
# mrc-0-002696: ['1948년', '1949년'] 중 1948년 (베이핑-톈진 전투가 시작된 연도는?)
# mrc-0-000564: ['1970년', '1835년'] 중 1835년 (여성 작가들이 언제부터 여성 등장인물에 관심을 가지기 시작했나요?)
# mrc-0-004323: ['강력범죄 특별수사관', '연극배우'] 중 강력범죄 특별수사관 (알렉스의 직업은?)
# mrc-0-000664: ['벤자민 바커', '벤저민 바커'] 중 벤자민 바커 (스위니 토드의 본명은?)
# mrc-0-004392: ['뇌 일부', '뇌'] 중 뇌 (모토코의 몸 중에 인공적인 기계장치로 되어 있지 않은 곳은?)
# mrc-0-000162: ['스타베크 포트발 크빈네르', '벨기에의 FC 브뤼셀'] 중 벨기에의 FC 브뤼셀 (최재수는 2012년에 어디로 이적했는가?)
# mrc-0-004085: ['신라 선덕여왕', 'R. H. 앨런'] 중 R. H. 앨런 (맥국이라는 명칭을 알린 사람은?)
# mrc-0-003807: ['키홀더', '날카롭게 간 키홀더'] 중 날카롭게 간 키홀더 (오두막의 첫 손님은 어떤 물건을 활용해 자살했는가?)
# mrc-0-004710: ['공훈의 보상', '다이라노 다다쓰네의 난'] 중 다이라노 다다쓰네의 난 (국내무사가 체포 활동에 참가한 것은 무엇 때문인가?)
# mrc-0-005012: ['이탈리아 요리', '파스타'] 중 이탈리아 요리 (미국에서 나폴리식 요리를 의미하는 요리는?)
# mrc-0-003770: ['명련사', '명련사이'] 중 명련사 (원래 요괴를 위해 만들었으나 차후 인간들의 신봉도 받게된 시설은?)
# mrc-0-004111: ['1924년', '1919년'] 중 1924년 (학생들이 일본인 선생들을 몰아내기 위해 동맹휴학 시위를 일으킨 해는 ?)
# mrc-1-001775: ['카르멜 수녀원', '암스테르담'] 중 암스테르담 (장면이 가족과 떨어져 거처를 옮긴 곳은?)
# mrc-1-000627: ['1967년 11월 15일', '9월 26일'] 중 1967년 11월 15일 (도무라 가즈사쿠가 대표로 있던 단체가 공산당과 결별을 선언했던 시기는?)
# mrc-1-001316: ['조선무선공학원', '창립기'] 중 조선무선공학원 (광운전자공과대학 이전에 사용되던 명칭은 무엇인가요?)
# mrc-1-000977: ["'나는 참된 보통 선거를 원한다'", "나는 참된 보통 선거를 원한다 (我要真普選)'"] 중 나는 참된 보통 선거를 원한다 (我要真普選) (하나를 철거하면 열을 건다' 운동에 사용된 플랜카드의 내용은?)
# mrc-0-003501: ['백병계열군', '백병전특화계열의 직업'] 중 백병전특화계열의 직업 (PK, 수탈을 목적으로 하는 플레이어에게 인기가 많은 직업군은?)
# mrc-1-000841: ['사돈인 한진창', '구 대한제국 대신들'] 중 사돈인 한진창 (윤치호가 고종 독살설을 믿게된 것은 누구 때문인가?)
# mrc-0-005486: ['조조', '이각(李傕) 등'] 중 조조 (헌제는 추격을 당하다 누구에게 도움을 청하였나요?)
# mrc-0-004410: ['세르게이 미로노프', '빌헬름 바이틀링'] 중 세르게이 미로노프 (사회민주주의와 민주사회주의를 합친 사상을 가진 집단의 우두머리는 누구인가?)
# mrc-0-001659: ['솔레놉신이', '유산'] 중 솔레놉신이 (인간에게 불타는 느낌의 아픔을 주는 것은?)
# mrc-0-001251: ['공화당원 투표인들 만을 화나게', '공화당원 투표인들 만을 화나게 할 것'] 중 공화당원 투표인들 만을 화나게 할 것 (듀이는 닉슨을 공천 후보에서 내리는 것이 어떤 결과를 초래할 것이라고 말했는가?)
# mrc-1-000177: ['제8조', '제3조'] 중 제8조 (조청상민수륙무역장정중의 8개조중, 장정의 개정에 대한 조항은?)
# mrc-1-001517: ['강원도 관찰사인', '강원도도장관'] 중 강원도 관찰사인 (이규완이 강원도에 철도 건설을 제안할 당시 직책은 무엇이었는가?)
# mrc-0-003711: ['성철(이영주)', '성철'] 중 성철(이영주) (법맥과 전등을 중시하면 스승없이 깨달음을 얻을 수 없다고 주장한 사람은?)
# mrc-0-004335: ['뉴욕타임스', '일간 뉴욕타임스'] 중 뉴욕타임스 (중국 공산당원과 가족의 미국 입국 금지 방안 검토와 관련된 마이크 폼페이오 장관의 입장을 보도한 언론은?)
# mrc-0-003436: ['주노 해변', '디에프 해변'] 중 주노 해변 (제2캐나다기갑여단이 상륙한 곳은?)
# mrc-0-002605: ['수수께끼의 콘드률', '콘드률'] 중 콘드률 (구립운석을 이루는 물질 중 널리 알려진 것은?)
#
# ### 모두 다른 답변 (GPT 선택) ###
# mrc-1-000653: ['사만', '사만 행성', '지구'] 중 사만 행성 (유령'은 어느 행성에서 지구로 왔는가?)
# mrc-0-000854: ['1916년', '1971년', '2008년'] 중 1916년 (독일에서 외국 영화를 상영할 수 없게 된 연도는?)
# mrc-0-001235: ['황소자리 성류', '미치류의 화석이 전세계에 걸쳐 발견된다는 것', '화석'] 중 미치류의 화석이 전세계에 걸쳐 발견된다는 것 (미치류가 해안가를 통해 다른 곳으로 이동했다는 주장을 뒷받침하는 것은?)
# mrc-1-000813: ['태풍 초이완이 마리아나 제도에서 벗어나자', '마리아나 제도', '9월 13일'] 중 마리아나 제도, 9월 13일 (태풍 초이완의 경보는 어떤 순간부터 풀렸는가?)
# mrc-0-001699: ['SI 단위계', '미터법', 'SI'] 중 SI (질량을 킬로그램으로 정의하는 단위 규칙은 무엇인가?)
# mrc-0-001884: ['상반신', '하반신', '복잡한 2족 보행기구'] 중 복잡한 2족 보행기구 (레빌 장군은 무엇이 없었기 때문에 실망했나?)
# mrc-0-003205: ['조선후기', '고려 초경', '조선후기에'] 중 조선후기 (석조지장보살상이 조각되지 않았을 것으로 추정되는 시기는?)
# mrc-0-000359: ['독일', '독일군', '프랑스'] 중 독일군 (제1차 마른강 전투에서 이긴 국가는?)
# mrc-0-001382: ['이집트', '스페인', '프랑스'] 중 이집트 (로마의 인력 수급에 중요한 역할을 한 나라는?)
# mrc-0-002723: ['건강 증서', '"건강 증서"', '건강증서'] 중 건강증서 (화물과 배가 시내 가까이에 갈 수 있는지의 여부를 정하는 기준이 된 문서는?)
# mrc-0-001445: ['1918년까지', '1960년 초반 아프리카인들의 독립 이전까지', '1960년 초반 아프리카인들의 독립 이전'] 중 1918년까지 (독일의 식민 지배는 언제까지 지속됐는가?)
# mrc-1-000536: ['장래의 시장 상황이 불투명', '양극화', '장래의 시장 상황이 불투명하다면'] 중 양극화 (안전한 거래를 지지하는 주식 시장 참여자들은 어떤 집단 극화 양상을 보이나요?)
# mrc-0-005293: ['밀리켄역', '케네디역', '유니언역'] 중 유니언역 (1985년 스토우빌선 열차가 스토우빌에서 출발해 여섯 번째로 정차했던 역은?)
# mrc-1-001543: ['머나먼 다리', '밴드 오브 브라더스', '영화 머나먼 다리'] 중 머나먼 다리 (마켓가든 작전을 다룬 작품은?)
# mrc-0-002231: ['악령', '<고골에게 보내는 편지>', '사회적인 희곡'] 중 사회적인 희곡 (정치적 코미트를 담고있는 작품은?)
# mrc-0-001961: ['남서풍', '북동풍', '동남풍'] 중 남서풍 (낮에는 어떤 바람이 부는가?)
# mrc-0-004196: ['우주 토끼', '요로감염증', '합병증'] 중 합병증 (루이가 사망하게 될 원인은 무엇인가?)
# mrc-0-001778: ['1072년', '1045년', '1953년'] 중 1045년 (고스자쿠 천황이 사망한 연도는?)
# mrc-0-002074: ['3턴', '5턴', '최대 10일'] 중 3턴 (야전의 전투 제한 시간은?)
# mrc-1-000580: ['장웅', '오토야', '히스토리아가'] 중 오토야 (키요미와 자신이 아끼는 2명을 지키기 위해 목숨도 아까워 하지 않은 사람은?)
# mrc-0-004245: ['농상무대신', '외무대신', '외무대신과 농상무대신'] 중 외무대신과 농상무대신 (이토 히로부미가 정치적 대립관계인 오쿠마 시게노부에게 준 관직은?)
# mrc-0-000500: ['2006년', '2008년', '2009년'] 중 2008년 (진관희가 짧은 기자 회견을 가진 해는?)
# mrc-1-001071: ['남자아이 빈을 데려다 양자로 삼', '남자아이 빈을 데려다 양자', '남자아이 빈을 데려다 양자로 삼는다.'] 중 남자아이 빈을 데려다 양자로 삼는다. (좌운검이 도연이 정조의 자손인 것을 아무도 모르게 하기 위해 한 행동은?)
# mrc-1-001269: ['제임스 패닌', '패닌', '제임스 패닌 대령'] 중 제임스 패닌 (에이몬 b. 킹을 파견한 사람은?)
# mrc-1-000870: ['아즈마(東)', '마하프라즈냐파라미타샤스트라(Mahaprajnaparamita\xadsastra)', '이즈마 하치로로'] 중 아즈마(東) (아즈마의 초기 명칭은?)
# mrc-0-000527: ['순우리말 이름', '보물', '과학의 중요성'] 중 보물 (조선박물연구회가 공포하고자 한 것은?)
# mrc-1-000278: ['차벽을 만드는 방법', '정보공개', '사전 구속 영장'] 중 정보공개 (청구취지는 밝히는 방법은?)
# mrc-1-000094: ['구와바라', '구와바라 다케오', '구와바라 다케오(桑原武夫, 교토대 명예교수)'] 중 구와바라 다케오(桑原武夫, 교토대 명예교수) (가와바타가 술 '고도'를 직접 사와서 시음시킨 사람은?)
# mrc-1-000972: ['미노프스키 입자', '염소가스', '미노프스키 입자 산포'] 중 미노프스키 입자 산포 (연방군의 레이다를 무력화시킨 화학무기는?)
# mrc-0-000030: ['1643년', "'관왕묘'", '영천 숭렬당'] 중 영천 숭렬당 (수사들이 전쟁의 대가로 지은 건물은?)
# mrc-0-001878: ['입석대(立石臺)', '입석대', '문장대'] 중 입석대 (속리산에서 임경업 장군의 설화가 깃들어있는 곳은 어디인가?)
# mrc-0-003441: ['라트비아', '렌나르트', '인민전선'] 중 렌나르트 (에스토니아는 희망을 가졌는가' 를 발표한 인물이 리투아니와 협력한 떄는?)
# mrc-1-000524: ['밀로셰비치', '슬로보단 밀로셰비치', '세르비아의 대통령 슬로보단 밀로셰비치'] 중 슬로보단 밀로셰비치 (인민군이 세르비아를 확장하는 쪽으로 돌아서게 만든 사람은?)
# mrc-1-001426: ['중재위원회를 설치하자고 공식적으로 요청', '수출 규제 해제 요청', '직선기선'] 중 중재위원회를 설치하자고 공식적으로 요청 (한국이 무시한 일본 측의 주장은?)
# mrc-0-004308: ['폭스바겐 제타', 'Beetles(딱정벌레)', "'Beetles(딱정벌레)'"] 중 Beetles(딱정벌레) (폭스바겐이 곤충명을 이름으로 지은 차량은?)
# mrc-0-002991: ['프리큐어들', '사카가미 아유미', '스마일과 스위트 멤버들이'] 중 프리큐어들 (처음에는 후짱을 반대했지만 마지막에 후짱의 도움을 받은 인물은?)
#
# 최종 결과가 'final_mrc_results2.json'에 저장되었습니다.

# %%
# Out:
#      title                                            context  \
# 0    미국 상원  미국 상의원 또는 미국 상원(United States Senate)은 양원제인 미국...
# 1   인사조직관리  '근대적 경영학' 또는 '고전적 경영학'에서 현대적 경영학으로 전환되는 시기는 19...
# 2      강희제  강희제는 강화된 황권으로 거의 황제 중심의 독단적으로 나라를 이끌어 갔기에 자칫 전...
# 3   금동삼존불감  불상을 모시기 위해 나무나 돌, 쇠 등을 깎아 일반적인 건축물보다 작은 규모로 만든...
# 4  계사명 사리구  동아대학교박물관에서 소장하고 있는 계사명 사리구는 총 4개의 용기로 구성된 조선후기...
#
#                                   question  \
# 0         대통령을 포함한 미국의 행정부 견제권을 갖는 국가 기관은?
# 1                   현대적 인사조직관리의 시발점이 된 책은?
# 2           강희제가 1717년에 쓴 글은 누구를 위해 쓰여졌는가?
# 3  11~12세기에 제작된 본존불은 보통 어떤 나라의 특징이 전파되었나요?
# 4               명문이 적힌 유물을 구성하는 그릇의 총 개수는?
#
#                                          answers  document_id
# 0        {'answer_start': [235], 'text': ['하원']}        18293
# 1  {'answer_start': [212], 'text': ['《경영의 실제》']}        51638
# 2        {'answer_start': [510], 'text': ['백성']}         5028
# 3        {'answer_start': [625], 'text': ['중국']}        34146
# 4         {'answer_start': [30], 'text': ['4개']}        47334

# %%
from transformers import RobertaForSequenceClassification, AutoTokenizer, Trainer, TrainingArguments
from datasets import Dataset
import torch

# GPU 사용이 가능한지 확인
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# RoBERTa 모델 및 토크나이저 불러오기
model_name = "roberta-base"  # 사용할 사전 학습 모델
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = RobertaForSequenceClassification.from_pretrained(model_name, num_labels=2)  # 이진 분류니까 num_labels=2

# 모델을 CUDA로 이동 (GPU 사용)
model.to(device)
# Out:
# C:\Users\spdlq\.conda\envs\boost-camp1\lib\site-packages\huggingface_hub\file_download.py:1142: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at C:\Users\spdlq/.cache\huggingface\hub\models--roberta-base\snapshots\e2da8e2f811d1448a5b465c236feacd80ffbac7b\config.json
# Model config RobertaConfig {
#   "_name_or_path": "roberta-base",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.24.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading file vocab.json from cache at C:\Users\spdlq/.cache\huggingface\hub\models--roberta-base\snapshots\e2da8e2f811d1448a5b465c236feacd80ffbac7b\vocab.json
# loading file merges.txt from cache at C:\Users\spdlq/.cache\huggingface\hub\models--roberta-base\snapshots\e2da8e2f811d1448a5b465c236feacd80ffbac7b\merges.txt
# loading file tokenizer.json from cache at C:\Users\spdlq/.cache\huggingface\hub\models--roberta-base\snapshots\e2da8e2f811d1448a5b465c236feacd80ffbac7b\tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at C:\Users\spdlq/.cache\huggingface\hub\models--roberta-base\snapshots\e2da8e2f811d1448a5b465c236feacd80ffbac7b\tokenizer_config.json
# loading configuration file config.json from cache at C:\Users\spdlq/.cache\huggingface\hub\models--roberta-base\snapshots\e2da8e2f811d1448a5b465c236feacd80ffbac7b\config.json
# Model config RobertaConfig {
#   "_name_or_path": "roberta-base",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.24.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading configuration file config.json from cache at C:\Users\spdlq/.cache\huggingface\hub\models--roberta-base\snapshots\e2da8e2f811d1448a5b465c236feacd80ffbac7b\config.json
# Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.24.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading weights file model.safetensors from cache at C:\Users\spdlq/.cache\huggingface\hub\models--roberta-base\snapshots\e2da8e2f811d1448a5b465c236feacd80ffbac7b\model.safetensors
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.dense.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# RobertaForSequenceClassification(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): RobertaClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=2, bias=True)
#   )
# )

# %%
# 학습을 위한 `all_matching` 데이터를 Dataset 형태로 변환
def preprocess_function(examples):
    return tokenizer(examples['question'], examples['answer'], truncation=True, padding=True)

# `all_matching` 데이터를 Hugging Face Dataset으로 변환 (예: all_matching은 딕셔너리 형태로 가정)
all_matching_data = [{"question": q, "answer": a, "label": 1} for q, a in all_matching.items()]  # label=1로 설정
train_dataset = Dataset.from_list(all_matching_data)

# 평가를 위한 `eval_dataset` 설정
eval_dataset = train_dataset.train_test_split(test_size=0.1)["test"]  # 데이터의 10%를 평가용으로 사용

# 토큰화 및 데이터 전처리
train_dataset = train_dataset.map(preprocess_function, batched=True)
eval_dataset = eval_dataset.map(preprocess_function, batched=True)

# 학습 설정
training_args = TrainingArguments(
    output_dir='./results',
    evaluation_strategy="epoch",     # 매 epoch마다 평가 진행
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    weight_decay=0.01
)

# 트레이너 설정 (eval_dataset 추가)
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset  # 평가 데이터셋 추가
)

# 모델 학습
trainer.train()

# 모델을 평가 모드로 전환 (추론을 위해)
model.eval()
# Out:
# Map: 100%|██████████| 5331/5331 [00:00<00:00, 17735.26 examples/s]
# Map: 100%|██████████| 593/593 [00:00<00:00, 15105.93 examples/s]
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# The following columns in the training set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: question, answer. If question, answer are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# C:\Users\spdlq\.conda\envs\boost-camp1\lib\site-packages\transformers\optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 5331
#   Num Epochs = 3
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 2001
#   Number of trainable parameters = 124647170
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 41
#      33 trainer = Trainer(
#      34     model=model,
#      35     args=training_args,
#      36     train_dataset=train_split,
#      37     eval_dataset=eval_split  # 평가 데이터셋 추가
#      38 )
#      40 # 모델 학습
# ---> 41 trainer.train()
#      43 # 모델을 평가 모드로 전환 (추론을 위해)
#      44 model.eval()
#
# File ~\.conda\envs\boost-camp1\lib\site-packages\transformers\trainer.py:1501, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1496     self.model_wrapped = self.model
#    1498 inner_training_loop = find_executable_batch_size(
#    1499     self._inner_training_loop, self._train_batch_size, args.auto_find_batch_size
#    1500 )
# -> 1501 return inner_training_loop(
#    1502     args=args,
#    1503     resume_from_checkpoint=resume_from_checkpoint,
#    1504     trial=trial,
#    1505     ignore_keys_for_eval=ignore_keys_for_eval,
#    1506 )
#
# File ~\.conda\envs\boost-camp1\lib\site-packages\transformers\trainer.py:1749, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1747         tr_loss_step = self.training_step(model, inputs)
#    1748 else:
# -> 1749     tr_loss_step = self.training_step(model, inputs)
#    1751 if (
#    1752     args.logging_nan_inf_filter
#    1753     and not is_torch_tpu_available()
#    1754     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    1755 ):
#    1756     # if loss is nan or inf simply add the average of previous logged losses
#    1757     tr_loss += tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File ~\.conda\envs\boost-camp1\lib\site-packages\transformers\trainer.py:2508, in Trainer.training_step(self, model, inputs)
#    2505     return loss_mb.reduce_mean().detach().to(self.args.device)
#    2507 with self.compute_loss_context_manager():
# -> 2508     loss = self.compute_loss(model, inputs)
#    2510 if self.args.n_gpu > 1:
#    2511     loss = loss.mean()  # mean() to average on multi-gpu parallel training
#
# File ~\.conda\envs\boost-camp1\lib\site-packages\transformers\trainer.py:2553, in Trainer.compute_loss(self, model, inputs, return_outputs)
#    2551 else:
#    2552     if isinstance(outputs, dict) and "loss" not in outputs:
# -> 2553         raise ValueError(
#    2554             "The model did not return a loss from the inputs, only the following keys: "
#    2555             f"{','.join(outputs.keys())}. For reference, the inputs it received are {','.join(inputs.keys())}."
#    2556         )
#    2557     # We don't use .loss here since the model may return tuples instead of ModelOutput.
#    2558     loss = outputs["loss"] if isinstance(outputs, dict) else outputs[0]
#
# ValueError: The model did not return a loss from the inputs, only the following keys: logits. For reference, the inputs it received are input_ids,attention_mask.

# %%
def choose_best_answer(model, tokenizer, question, answer1, answer2, device):
    # 입력 문장 토큰화 및 텐서 변환
    inputs_1 = tokenizer(question, answer1, return_tensors="pt", truncation=True, padding=True).to(device)
    inputs_2 = tokenizer(question, answer2, return_tensors="pt", truncation=True, padding=True).to(device)

    # 각 입력에 대해 BERT 모델의 출력(logits)을 얻음
    with torch.no_grad():
        outputs_1 = model(**inputs_1).logits
        outputs_2 = model(**inputs_2).logits

    # logits에서 더 큰 값을 가진 답변을 선택 (0 또는 1 예측)
    if outputs_1.argmax() == outputs_2.argmax():
        return answer1 if outputs_1[0][1] > outputs_2[0][1] else answer2
    else:
        return answer1 if outputs_1.argmax() == 1 else answer2

# %%
# 2개의 답변이 있는 경우 선택하기
two_matching_final = {}
for question_id, answers in two_matching.items():
    question = id_to_question.get(question_id, "질문 없음")
    answer1, answer2 = answers
    best_answer = choose_best_answer(model, tokenizer, question, answer1, answer2, device)
    two_matching_final[question_id] = best_answer
    print(f"{question_id}: {best_answer} (질문: {question})")

# 여러 개의 답변이 있는 경우 선택하기
none_matching_final = {}
for question_id, answers in none_matching.items():
    question = id_to_question.get(question_id, "질문 없음")
    # 두 개씩 비교하며 최종 답을 찾아야 함 (예: 답변 3개일 때 차례대로 비교)
    best_answer = answers[0]
    for answer in answers[1:]:
        best_answer = choose_best_answer(model, tokenizer, question, best_answer, answer, device)
    none_matching_final[question_id] = best_answer
    print(f"{question_id}: {best_answer} (질문: {question})")
# Out:
# mrc-0-005021: 91년 체제 (질문: 상류 부르주아의 정치 독점을 불러일으킨 체계는?)
# mrc-1-000163: 구미호 (질문: 아시노 호가 만들어진 원인은 무엇인가?)
# mrc-0-000439: 점쟁이 (질문: 클레어에게 오세아닉 815편을 타라고 말한 사람의 이름은?)
# mrc-0-000901: 오시노 메메 (질문: 괴수로부터 메구밍을 구해준 사람은 누구인가?)
# mrc-0-001326: 《뉴스피플》 (질문: 이유립씨가 1970년대 중반에 본인의 글을 기고하기 시작한 곳은?)
# mrc-0-003644: 백제 (질문: 콘스탄티누스가 군사 4만 명을 이끌고 침범한 나라는?)
# mrc-0-000049: 서사 (질문: 루돌로지스트들이 게임에서 가장 주된 것이라 주장하는 것은?)
# mrc-0-001206: 1849년 (질문: 펌프가 발매된 해는 언제인가?)
# mrc-0-003133: 책 (질문: 아델리 펭귄의 목숨에 지장을 주는 사람의 업종은 무엇인가요?)
# mrc-0-001058: 카필라 성 (질문: 석가모니 부처가 태어난 곳은 어디인가?)
# mrc-0-002361: 영토 (질문: 동맹을 맺음으로써 헝가리는 자유를 비롯해 무엇을 잃었나?)
# mrc-0-001086: 초계면 (질문: 8천 명의 시민들이 모여 대규모 시위를 벌인 지역은?)
# mrc-0-000624: 영국 (질문: 유로니우스를 살해한 용의자가 소속된 밴드의 국적은?)
# mrc-1-001280: 미국 대통령 우드로 윌슨 (질문: 자신이 고안한 14개조 평화원칙을 국제 사회에 발표하고 싶어한 인물은?)
# mrc-0-000504: 삼국시대 (질문: 팔과 다리가 밋밋한 형태인 신체표현은 어떤 시기를 반영한 것인가요?)
# mrc-0-003763: 광배(光背)의 뒷면 (질문: 불상에 대한 정보가 적혀있는 것은?)
# mrc-0-003896: 마튀랭 박사 (질문: 병으로 인해 피렌체의 수많은 사람들이 죽어갔음을 언급한 사람은?)
# mrc-0-003298: 김호 (질문: 1994년 FIFA 월드컵 당시 대한민국 축구 대표팀의 감독은 누구인가?)
# mrc-0-003628: 공유 필명 (질문: 선라이즈의 애니메이션 작품 기획부는 야타테 하지메를 무엇으로 사용하는가?)
# mrc-0-000432: 조선건국동맹 (질문: 여운형이 조동호와 함께 조직한 것은?)
# mrc-0-003364: 아우구스투스 시대 (질문: 단색 배경에 추상적인 디자인을 쓰는 양식이 유행하던 시기는?)
# mrc-0-003670: ‘마루게’ (질문: 최고령 초등학생으로 기네스북에 올라있는 사람은?)
# mrc-0-000386: 호세 1세 (질문: 628년에 새롭게 왕위에 오른 사람은 누구인가요?)
# mrc-0-004345: 2001년 (질문: 셰이크 무지부르 라흐만의 딸이 처음으로 선거에서 졌던 해는?)
# mrc-0-001470: 볼가 지방 (질문: 소설 <형제>의 작가가 태어난 지역은?)
# mrc-1-001239: 쉴드 빔 (질문: 무엇이 창 아래에 설치되어 표시기가 한 개 늘어났는가?)
# mrc-0-001940: 경문왕 (질문: 동화사 석조비로자나불이 제작될 때, 당시 임금은 누구였는가?)
# mrc-0-001241: 상업 분야 (질문: 협동 화폐 거래소의 인정은 어느 부문에서 나타나는 변화인가?)
# mrc-1-001457: 도요토미 히데요시 (질문: 조선역사를 수호하는데 위기를 제공한 사람은?)
# mrc-1-000908: 변비 (질문: 비자나무의 열매는 어떤 증상을 치료하기 위해 쓰이나요?)
# mrc-1-000116: 가이아 (질문: 튀폰의 아버지는 누구인가?)
# mrc-0-004669: 교황 (질문: 가톨릭 교회에서 주교에게 '최고사제'의 자격을 주는 직함의 이름은?)
# mrc-0-002210: 통인 주기 (질문: 아랑을 살해한 사람은?)
# mrc-1-000862: 설인귀 (질문: 당의 군대를 몰살시킨 사람은?)
# mrc-0-000986: 오스마르 (질문: 전반전이 6분이 지난 후 골을 넣은 선수는?)
# mrc-0-003970: 센리 선 (질문: 통근특급이 걸림돌인 노선과 서로 평면교차하는 노선은 어디인가?)
# mrc-0-000304: 1919년 1월26일 (질문: 국경일에 일장기를 달아도 반대하지 않을 것이라는 내용을 담은 윤치호의 일기는 언제 쓰여진 것인가?)
# mrc-1-001025: 티탄즈 (질문: 자미토프가 개혁을 강행하기 위해 설립한 사병 집단은?)
# mrc-0-001374: 1530년 (질문: 성 요한 기사단이 로도스 섬으로 거처를 옮긴 년도는?)
# mrc-0-001783: 자자 빙크스 (질문: 팰퍼틴에게 비상시의 권리를 도맡아 달라고 의견을 냈던 인물은?)
# mrc-0-005332: 동탁은잔 (질문: 날개 앞쪽으로 연꽃을 들고 있는 인면조가 그려진 백제의 유물은 무엇인가?)
# mrc-1-001594: 자유송환 (질문: 각 측에서 주장된 포로교환 방법 중 선택된 것은?)
# mrc-0-002938: 데이 페소 (질문: 티나헤로가 아칸바로의 유적을 날조한 것이라고 주장한 인물은?)
# mrc-0-002936: 붉은 군대 (질문: 메리의 사촌은 어디에서 영웅으로 활약하기도 했나요?)
# mrc-0-003706: 6신관 (질문: 마'를 피하기 위해 살몬 신전을 보낸 곳은?)
# mrc-0-001021: 보스턴의 폐공장 (질문: 타격이 시작되는 것은 대상이 어디에 나타날 때인가?)
# mrc-0-003236: 베를린 (질문: 작센군과 오스트리아군은 함께 어디를 공격할 예정이였나?)
# mrc-0-001379: 퓌르트 (질문: 네델란드와의 친선 경기에서 유일하게 골을 넣은 선수의 소속팀은?)
# mrc-0-004927: 대체 에너지의 개발 (질문: 아일랜드의 자원 공급 불안과 지구 온난화에 대한 해결방안은?)
# mrc-0-000576: 알 카포네 (질문: 히틀러의 반란은 누구를 모방한 것인가?)
# mrc-0-002786: 외교부 장관 (질문: 최초로 공산주의 정당을 제외한 선거 이후 메리가 맡은 직책은?)
# mrc-0-001105: 실존주의 (질문: 오노에게 영향을 미친 장 폴 사르트르의 철학은?)
# mrc-0-001896: P 시리즈 (질문: 산악 자전거 프리 라이드 부문에 출전하는 마틴 소더스트롬이 이용하는 제품은?)
# mrc-0-001887: 18세기 중후반 (질문: 부피와 무게감을 나타낸 얼굴이나 짧은 목 등을 통해 알 수 있는 불상의 축조 시기는?)
# mrc-1-001797: 감옥 (질문: 이경언이 사망한 장소는?)
# mrc-0-002028: 리을설 (질문: 김일성이 소련인으로서 살고 싶어했다고 말을 한 인물은?)
# mrc-0-003031: 당 태종 (질문: 고구려에 크게 지고 그 전쟁때문에 병이나서 죽은 당나라 왕은?)
# mrc-1-000235: '농지' (질문: 레닌에 의하면 자본주의식 농업 시스템을 통해 일반 시민들이 더 쉽게 사용할 수 있게 된 것은 무엇인가?)
# mrc-0-002716: 지에코초 (질문: 아르튀르가 베르린과의 연애생활을 한 경험을 쓴 시집이름은?)
# mrc-0-003961: 스기타 겐파쿠 (질문: 네덜란드어를 몰랐으나 타펠 아나토미아의 해부도 번역에 참여한 것은 누구인가?)
# mrc-1-001721: 이경희 (질문: 선생님에게 창씨개명을 하지 않겠다고 한 사람은?)
# mrc-0-004738: 헌법 (질문: 주권재민의 원칙은 어디에 명시되어 있는가?)
# mrc-1-001603: 법관 출신 인사 (질문: 21대 총선을 겨냥하여 사법개혁을 이끌어갈 수 있다는 것에 뒷받침된 명목은?)
# mrc-0-003356: 진주강씨 (질문: 윤치호의 아내는 누구의 부인을 방문했나?)
# mrc-1-000769: 제1대대 (질문: 107고지를 처음 함락시킨 부대는?)
# mrc-0-000114: 코드 (질문: 코드 서명이 보증하는 대상은?)
# mrc-0-002997: 1922년 (질문: 타누당(TANU)를 설립한 인물이 태어난 해는?)
# mrc-1-000889: 667년의 금산전투 (질문: 고구려와 당나라 사이에 4대 전투 중 유일하게 다른 해에 일어난 전투는?)
# mrc-1-000267: 3층 (질문: 도쇼구 역의 승강장은 몇 층에 있는가?)
# mrc-0-002654: 사운드클라우드 (질문: navigation'이 올라온 사이트는?)
# mrc-0-002758: 잉글랜드 (질문: 스위스가 월드컵에서 이긴 나라는?)
# mrc-1-001727: 수영공원 (질문: 경상좌도 수군절도사영이 관리했던 곳은?)
# mrc-0-004755: 장충단공원 (질문: 공원으로 변화되는 곳은?)
# mrc-0-002525: <<종횡무진 한국경제>> (질문: 장하준 교수의 한국경제에 대한 생각에 대해 반론한 김상조 교수의 저서는?)
# mrc-0-001847: 호해 (질문: 자신의 사리사욕만 채우며 무능했던 진나라의 황제는?)
# mrc-0-003215: 1773년 (질문: 보스턴 차 사건이 발발한 년도는?)
# mrc-0-001757: 《Nirvana》 (질문: Yoo Doo Right이 수록된 앨범명은?)
# mrc-0-004594: 외국인노동자의 정주화 방지 (질문: 외국인 근로자 고용 등에 대한 법률'의 목적은?)
# mrc-0-001133: 언카스 (질문: 17세기 피쿼트로부터 독립하여 모하칸족을 만든 사람은?)
# mrc-0-003821: 잉글랜드 (질문: 프랑스군은 마렝고에서 어떤 나라의 군대와 마주하였나?)
# mrc-0-001607: 스렝이 (질문: 누아다가 오른손이 없는 이유는 누구 때문인가?)
# mrc-0-003454: 16세기 (질문: 현대 식물원은 언제 오픈되었는가?)
# mrc-0-000206: 2월 혁명 (질문: 필리프가 왕실에서 쫒겨난 사건의 단초가 된 역사적 사건은?)
# mrc-0-003043: 수사1과 (질문: 시바사키의 이전 소속 부서는?)
# mrc-0-003434: 계획 경제 (질문: 평등과 복지 사회를 이루기 위해 필요한 것이라는 선전 하에 행해지는 것은?)
# mrc-0-001324: 부산 (질문: 《서편 삼층석탑》은 어느 지역의 유형문화재로 지정되어있나요?)
# mrc-0-002127: 4막 3장 (질문: 맬컴이 맥더프에게 상실에 슬퍼할 줄 알아야 함을 배우는 장은?)
# mrc-0-001438: 봉원사 (질문: 이보담은 어느 절에서 스님이 되었는가?)
# mrc-0-001415: 노룡군의 대장 (질문: 이무훈에게 살해당한 인물의 직책은?)
# mrc-1-000650: 광물 (질문: 조흔색은 무엇을 구별하는데 도움을 주나요?)
# mrc-0-003105: 4·19 폭동설’ (질문: 군부세력들이 어떤 상황을 빌미로 쿠테타를 일으키려고 했나?)
# mrc-0-002170: 《소우기》 (질문: 우치쿠라노 이시메가 작성한 내용이 실린 기록은 무엇인가요?)
# mrc-0-002414: 꼬리부분 (질문: 보디 스타킹에서 봉제되지 않은 부분은?)
# mrc-0-000668: 메란 (질문: 프랑크 왕족들의 무덤이 있는 곳은?)
# mrc-1-001689: 라위스달 (질문: 홉베마의 스승은 누구인가요?)
# mrc-0-002493: 미국 (질문: 쿠챤과 밀로셰비치의 협의에 대해서 작성한 작가의 출신국가는?)
# mrc-0-002092: 「소방공무원법」 (질문: 시도 도지사가 시도 소속 소방공무원을 임용할 수 있도록 개정된 법은?)
# mrc-1-001196: 4번째 외야수 (질문: 2016시즌 당시 테일러는 누구 대신 주전이 되었나?)
# mrc-0-002045: 송병하 (질문: 호연재 김씨의 시증조부는?)
# mrc-0-003645: <밤으로의 긴 여행> (질문: 손턴 와일더 사후, 최고의 명작으로 손꼽히는 작품은 무엇인가?)
# mrc-0-001272: 왕성 (질문: 신립이 스스로 목숨을 끊은 곳은?)
# mrc-0-003639: '온' (질문: 단어 '토레혼'의 어근은?)
# mrc-0-001046: 프랭클린 D. 루스벨트 (질문: 총선에서 듀이를 꺾은 사람은?)
# mrc-0-001863: 나스티카 (질문: 베단타 학파와 차르바카파는 무엇을 기준으로 나뉘어졌나요?)
# mrc-0-001123: 레반스라움 (질문: 토산물을 착취하는 등과 같은 업무의 명목은?)
# mrc-1-000056: 라크스 클라인 (질문: 프리덤 건담의 이름을 지은 사람은?)
# mrc-0-001192: 박근혜 대통령 (질문: 통진당을 해산시킨 결정을 인정한다고 직접 말한 인물은?)
# mrc-0-005108: 아도니스 (질문: 진홍빛 장미가 만들어진 원인을 제공한 자는?)
# mrc-1-000713: 티베트 (질문: 처음으로 염색된 섬유가 발견되었던 장소는?)
# mrc-0-004970: 한 번 (질문: 붉은자이언트날다람쥐 암컷의 일 년 평균 번식 횟수는?)
# mrc-1-000690: 하비 로우마이어 (질문: 레이가 골트 이후에 사용한 가짜 이름은 무엇인가요?)
# mrc-0-003499: 초음파 가습기 (질문: 물방울에 급수대의 이물질이 없는 가습기는?)
# mrc-0-004708: 위장 (질문: 어버이새가 새끼들의 먹이를 보관하는 곳은?)
# mrc-0-004579: 전라북도 전주 (질문: 경서교회를 설립한 사람이 태어난 도시는 어디인가?)
# mrc-0-000255: 실권 (질문: 사장이 부하직원에게 행사할 수 있는 권리는 무엇인가?)
# mrc-0-001539: 목포 (질문: 부부가 딸을 차에 태운 곳은?)
# mrc-0-005166: 괜찮다고 (질문: 행인의 플로이드가 코피난다는 말에 경찰관은 뭐라고 말했는가?)
# mrc-0-000150: 3-3 (질문: 아만시오가 처음으로 출전한 유럽대항전의 결과는?)
# mrc-0-000760: IP 주소 (질문: 다중 계정 사용자의 판별을 불가능하게 하는 것은?)
# mrc-0-004510: 인체의 치수 (질문: 인간에게 가장 익숙한 크기의 개념은 무엇인가요?)
# mrc-0-002482: 근원 마그마가 형성되는 기작 (질문: 발산형 경계와 수렴형경계의 마그마 점성이 다른 이유는?)
# mrc-1-001729: 수리물리학 (질문: 이론물리학에 비해 수학적인 부분을 더 강조하는 학문은?)
# mrc-0-004371: 원세훈 (질문: 역할을 가장 먼저 구체화 시킨 사람은?)
# mrc-0-002763: 개성 (질문: 신혜왕후가 묻혀있는 지역은?)
# mrc-0-001429: 독일 (질문: 요안니스 5세의 쿠테타를 지원한 것은 어느 나라인가?)
# mrc-0-004649: 내각 (질문: 히틀러의 권한을 합법적으로 확대시켜준 국가 기관은?)
# mrc-0-004438: 교란 요인을 통제하는 것 (질문: 연구자들이 설계된 실험실을 이용하는 것은 무엇을 위해서인가?)
# mrc-0-005422: '옥시전 디스트로이어' (질문: 세리자와 박사가 숨기려고 한 것은?)
# mrc-0-000394: 김영춘 (질문: 조선인민공화국에서 최고로 높은 직위에 오른 자는?)
# mrc-0-002289: 가덕도 (질문: 조선수군의 길목을 차단하기 위해 일본군이 설치한 왜성이 위치한 장소는?)
# mrc-0-003038: 에우리아의 요한 (질문: 알키온의 주교 자리를 빼앗은 사람은?)
# mrc-0-001682: 무죄 (질문: 보닌이 살인 혐의로 체포되어 받은 형벌은?)
# mrc-0-001457: 세르비아 (질문: 러시아가 동원령을 내린 것은 어느 나라를 견제하기 위해서인가?)
# mrc-0-003755: 무신 (질문: 정중부의 난 이전 병권을 장악한 집단은?)
# mrc-0-002696: 1949년 (질문: 베이핑-톈진 전투가 시작된 연도는?)
# mrc-0-000564: 1835년 (질문: 여성 작가들이 언제부터 여성 등장인물에 관심을 가지기 시작했나요?)
# mrc-0-004323: 연극배우 (질문: 알렉스의 직업은?)
# mrc-0-000664: 벤저민 바커 (질문: 스위니 토드의 본명은?)
# mrc-0-004392: 뇌 (질문: 모토코의 몸 중에 인공적인 기계장치로 되어 있지 않은 곳은?)
# mrc-0-000162: 벨기에의 FC 브뤼셀 (질문: 최재수는 2012년에 어디로 이적했는가?)
# mrc-0-004085: R. H. 앨런 (질문: 맥국이라는 명칭을 알린 사람은?)
# mrc-0-003807: 키홀더 (질문: 오두막의 첫 손님은 어떤 물건을 활용해 자살했는가?)
# mrc-0-004710: 공훈의 보상 (질문: 국내무사가 체포 활동에 참가한 것은 무엇 때문인가?)
# mrc-0-005012: 파스타 (질문: 미국에서 나폴리식 요리를 의미하는 요리는?)
# mrc-0-003770: 명련사 (질문: 원래 요괴를 위해 만들었으나 차후 인간들의 신봉도 받게된 시설은?)
# mrc-0-004111: 1919년 (질문: 학생들이 일본인 선생들을 몰아내기 위해 동맹휴학 시위를 일으킨 해는 ?)
# mrc-1-001775: 암스테르담 (질문: 장면이 가족과 떨어져 거처를 옮긴 곳은?)
# mrc-1-000627: 9월 26일 (질문: 도무라 가즈사쿠가 대표로 있던 단체가 공산당과 결별을 선언했던 시기는?)
# mrc-1-001316: 창립기 (질문: 광운전자공과대학 이전에 사용되던 명칭은 무엇인가요?)
# mrc-1-000977: '나는 참된 보통 선거를 원한다' (질문: 하나를 철거하면 열을 건다' 운동에 사용된 플랜카드의 내용은?)
# mrc-0-003501: 백병계열군 (질문: PK, 수탈을 목적으로 하는 플레이어에게 인기가 많은 직업군은?)
# mrc-1-000841: 구 대한제국 대신들 (질문: 윤치호가 고종 독살설을 믿게된 것은 누구 때문인가?)
# mrc-0-005486: 조조 (질문: 헌제는 추격을 당하다 누구에게 도움을 청하였나요?)
# mrc-0-004410: 세르게이 미로노프 (질문: 사회민주주의와 민주사회주의를 합친 사상을 가진 집단의 우두머리는 누구인가?)
# mrc-0-001659: 유산 (질문: 인간에게 불타는 느낌의 아픔을 주는 것은?)
# mrc-0-001251: 공화당원 투표인들 만을 화나게 (질문: 듀이는 닉슨을 공천 후보에서 내리는 것이 어떤 결과를 초래할 것이라고 말했는가?)
# mrc-1-000177: 제8조 (질문: 조청상민수륙무역장정중의 8개조중, 장정의 개정에 대한 조항은?)
# mrc-1-001517: 강원도도장관 (질문: 이규완이 강원도에 철도 건설을 제안할 당시 직책은 무엇이었는가?)
# mrc-0-003711: 성철 (질문: 법맥과 전등을 중시하면 스승없이 깨달음을 얻을 수 없다고 주장한 사람은?)
# mrc-0-004335: 뉴욕타임스 (질문: 중국 공산당원과 가족의 미국 입국 금지 방안 검토와 관련된 마이크 폼페이오 장관의 입장을 보도한 언론은?)
# mrc-0-003436: 주노 해변 (질문: 제2캐나다기갑여단이 상륙한 곳은?)
# mrc-0-002605: 콘드률 (질문: 구립운석을 이루는 물질 중 널리 알려진 것은?)
# mrc-1-000653: 지구 (질문: 유령'은 어느 행성에서 지구로 왔는가?)
# mrc-0-000854: 1916년 (질문: 독일에서 외국 영화를 상영할 수 없게 된 연도는?)
# mrc-0-001235: 화석 (질문: 미치류가 해안가를 통해 다른 곳으로 이동했다는 주장을 뒷받침하는 것은?)
# mrc-1-000813: 9월 13일 (질문: 태풍 초이완의 경보는 어떤 순간부터 풀렸는가?)
# mrc-0-001699: SI (질문: 질량을 킬로그램으로 정의하는 단위 규칙은 무엇인가?)
# mrc-0-001884: 하반신 (질문: 레빌 장군은 무엇이 없었기 때문에 실망했나?)
# mrc-0-003205: 고려 초경 (질문: 석조지장보살상이 조각되지 않았을 것으로 추정되는 시기는?)
# mrc-0-000359: 독일 (질문: 제1차 마른강 전투에서 이긴 국가는?)
# mrc-0-001382: 이집트 (질문: 로마의 인력 수급에 중요한 역할을 한 나라는?)
# mrc-0-002723: "건강 증서" (질문: 화물과 배가 시내 가까이에 갈 수 있는지의 여부를 정하는 기준이 된 문서는?)
# mrc-0-001445: 1918년까지 (질문: 독일의 식민 지배는 언제까지 지속됐는가?)
# mrc-1-000536: 양극화 (질문: 안전한 거래를 지지하는 주식 시장 참여자들은 어떤 집단 극화 양상을 보이나요?)
# mrc-0-005293: 유니언역 (질문: 1985년 스토우빌선 열차가 스토우빌에서 출발해 여섯 번째로 정차했던 역은?)
# mrc-1-001543: 머나먼 다리 (질문: 마켓가든 작전을 다룬 작품은?)
# mrc-0-002231: 악령 (질문: 정치적 코미트를 담고있는 작품은?)
# mrc-0-001961: 남서풍 (질문: 낮에는 어떤 바람이 부는가?)
# mrc-0-004196: 합병증 (질문: 루이가 사망하게 될 원인은 무엇인가?)
# mrc-0-001778: 1045년 (질문: 고스자쿠 천황이 사망한 연도는?)
# mrc-0-002074: 5턴 (질문: 야전의 전투 제한 시간은?)
# mrc-1-000580: 장웅 (질문: 키요미와 자신이 아끼는 2명을 지키기 위해 목숨도 아까워 하지 않은 사람은?)
# mrc-0-004245: 외무대신 (질문: 이토 히로부미가 정치적 대립관계인 오쿠마 시게노부에게 준 관직은?)
# mrc-0-000500: 2006년 (질문: 진관희가 짧은 기자 회견을 가진 해는?)
# mrc-1-001071: 남자아이 빈을 데려다 양자 (질문: 좌운검이 도연이 정조의 자손인 것을 아무도 모르게 하기 위해 한 행동은?)
# mrc-1-001269: 패닌 (질문: 에이몬 b. 킹을 파견한 사람은?)
# mrc-1-000870: 이즈마 하치로로 (질문: 아즈마의 초기 명칭은?)
# mrc-0-000527: 보물 (질문: 조선박물연구회가 공포하고자 한 것은?)
# mrc-1-000278: 사전 구속 영장 (질문: 청구취지는 밝히는 방법은?)
# mrc-1-000094: 구와바라 (질문: 가와바타가 술 '고도'를 직접 사와서 시음시킨 사람은?)
# mrc-1-000972: 염소가스 (질문: 연방군의 레이다를 무력화시킨 화학무기는?)
# mrc-0-000030: 1643년 (질문: 수사들이 전쟁의 대가로 지은 건물은?)
# mrc-0-001878: 입석대 (질문: 속리산에서 임경업 장군의 설화가 깃들어있는 곳은 어디인가?)
# mrc-0-003441: 인민전선 (질문: 에스토니아는 희망을 가졌는가' 를 발표한 인물이 리투아니와 협력한 떄는?)
# mrc-1-000524: 밀로셰비치 (질문: 인민군이 세르비아를 확장하는 쪽으로 돌아서게 만든 사람은?)
# mrc-1-001426: 직선기선 (질문: 한국이 무시한 일본 측의 주장은?)
# mrc-0-004308: 'Beetles(딱정벌레)' (질문: 폭스바겐이 곤충명을 이름으로 지은 차량은?)
# mrc-0-002991: 사카가미 아유미 (질문: 처음에는 후짱을 반대했지만 마지막에 후짱의 도움을 받은 인물은?)

# %%
# 최종 결과 통합
final_results = all_matching.copy()
final_results.update(two_matching_final)
final_results.update(none_matching_final)

# 결과를 json 파일로 저장
with open("final_mrc_results(roberta).json", "w", encoding='utf-8') as f:
    json.dump(final_results, f, indent=4, ensure_ascii=False)

print("최종 결과가 'final_mrc_results(roberta).json'에 저장되었습니다.")
# Out:
# 최종 결과가 'final_mrc_results(roberta).json'에 저장되었습니다.
