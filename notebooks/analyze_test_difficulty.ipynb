# %% [markdown]
# # 상위권 예측 결과 분석

# %% [markdown]
# ### prediction.json 병합

# %%
import json
import os
from collections import defaultdict


def merge_json_files(directory_path, output_file):
    # 결과를 저장할 딕셔너리 생성
    merged_data = defaultdict(list)

    # 디렉토리 내의 모든 JSON 파일 처리
    for filename in os.listdir(directory_path):
        if filename.endswith(".json"):
            file_path = os.path.join(directory_path, filename)
            with open(file_path, "r", encoding="utf-8") as file:
                data = json.load(file)
                # 각 키-값 쌍을 merged_data에 추가
                for key, value in data.items():
                    merged_data[key].append(value)

    # 결과를 새 JSON 파일로 저장
    with open(output_file, "w", encoding="utf-8") as outfile:
        json.dump(dict(merged_data), outfile, ensure_ascii=False, indent=4)

    print(f"병합된 데이터가 {output_file}에 저장되었습니다.")

# %%
# json 병합
directory_path = "./data/hard_ensemble"  # JSON 파일이 있는 디렉토리 경로
output_file = "./data/merged_output.json"  # 결과를 저장할 파일 이름
merge_json_files(directory_path, output_file)
# Out:
# 병합된 데이터가 ./data/merged_output.json에 저장되었습니다.

# %% [markdown]
# ### 난이도별로 json 분리

# %%
from collections import Counter, defaultdict


def classify_difficulty(data):
    difficulty_levels = defaultdict(list)

    for key, values in data.items():
        value_counts = Counter(values)
        max_count = max(value_counts.values())

        if max_count <= 2:
            difficulty_levels["어려움"].append({key: values})
        elif 3 <= max_count <= 5:
            difficulty_levels["중간"].append({key: values})
        elif 6 <= max_count <= 8:
            difficulty_levels["쉬움"].append({key: values})

    return difficulty_levels


def save_difficulty_levels(difficulty_levels):
    for difficulty, items in difficulty_levels.items():
        filename = f"{difficulty}.json"
        with open(filename, "w", encoding="utf-8") as outfile:
            json.dump(items, outfile, ensure_ascii=False, indent=4)

# %%
# json 파일 불러오기
file_path = "./data/merged_output.json"
with open(file_path, "r", encoding="utf-8") as file:
    data = json.load(file)
# 난이도 분류
classified_data = classify_difficulty(data)
# 분류된 데이터 저장
save_difficulty_levels(classified_data)
print("데이터가 난이도별로 분류되어 저장되었습니다.")

# %% [markdown]
# ### Question & Prediction 분석

# %%
import pandas as pd

pd.options.display.max_colwidth = 200
pd.set_option("display.max_rows", 30)

# %%
import pandas as pd
import json
from collections import Counter

# CSV 파일 로드
df = pd.read_csv("data/test_validation_dataset.csv")

# JSON 파일 로드
with open("data/merged_output.json", "r", encoding="utf-8") as f:
    json_data = json.load(f)


# 동일 예측 개수 반환
def determine_difficulty(values):
    value_counts = Counter(values)
    max_count = max(value_counts.values())
    return max_count

# predictions와 difficulty 컬럼 추가
df["predictions"] = df["id"].map(json_data)
df["difficulty"] = df["predictions"].apply(determine_difficulty)

# 컬럼 위치 변경
df = df[["id", "question", "predictions", "difficulty"]]

df.head()
# Out:
#              id                                 question  \
# 0  mrc-1-000653                    유령'은 어느 행성에서 지구로 왔는가?
# 1  mrc-1-001113          용병회사의 경기가 좋아진 것은 무엇이 끝난 이후부터인가?
# 2  mrc-0-002191  돌푸스에게 불특정 기간동안 하원이 잠시 쉬는 것을 건의 받았던 인물은?
# 3  mrc-0-003951     마오리언어와 영어, 뉴질랜드 수화를 공식 언어로 사용하는 나라는?
# 4  mrc-1-001272               디엔비엔푸 전투에서 보응우옌잡이 상대한 국가는?
#
#                                                                                        predictions  \
# 0                                      [우스, 사만 행성, 사만, 베텔게우스(Betelgeuse) 근처의 작은 행성, 지구, 사만, 사만 행성]
# 1                                                                  [냉전, 냉전, 냉전, 냉전, 냉전, 냉전, 냉전 종식]
# 2  [빌헬름 미클라스, 빌헬름 미클라스, 대통령인 빌헬름 미클라스, 대통령인 빌헬름 미클라스, 대통령인 빌헬름 미클라스, 대통령인 빌헬름 미클라스, 대통령인 빌헬름 미클라스]
# 3                                                       [뉴질랜드, 뉴질랜드, 뉴질랜드, 뉴질랜드, 뉴질랜드, 뉴질랜드, 뉴질랜드]
# 4                                                             [프랑스, 프랑스, 프랑스군, 프랑스, 프랑스, 프랑스, 프랑스]
#
#    difficulty
# 0           2
# 1           6
# 2           5
# 3           7
# 4           6

# %%
df["difficulty"].value_counts()
# Out:
# difficulty
# 7    241
# 6     90
# 5     77
# 3     77
# 4     76
# 2     30
# 1      9
# Name: count, dtype: int64

# %%
# 혼자 다른 값을 가진 인덱스의 빈도를 계산하는 함수
def count_unique_indices(predictions_list):
    n = len(predictions_list)
    counts = [0] * n

    for i in range(n):
        if predictions_list.count(predictions_list[i]) == 1:
            counts[i] += 1

    return counts


# 전체 데이터프레임에 대해 인덱스별 카운트 계산
all_counts = df["predictions"].apply(count_unique_indices)

# 인덱스별 총 카운트 계산
total_counts = [sum(counts) for counts in zip(*all_counts)]

print("각 인덱스별 혼자 다른 값의 총 개수:")
for idx, count in enumerate(total_counts):
    print(f"Index {idx}: {count}")
# Out:
# 각 인덱스별 혼자 다른 값의 총 개수:
# Index 0: 105
# Index 1: 76
# Index 2: 76
# Index 3: 80
# Index 4: 103
# Index 5: 63
# Index 6: 77

# %%
df[df["difficulty"]==1]
# Out:
#                id                 question  \
# 7    mrc-1-000163    아시노 호가 만들어진 원인은 무엇인가?
# 150  mrc-1-000116           튀폰의 아버지는 누구인가?
# 256  mrc-0-002231       정치적 코미트를 담고있는 작품은?
# 300  mrc-0-004196     루이가 사망하게 될 원인은 무엇인가?
# 460  mrc-1-000870             아즈마의 초기 명칭은?
# 472  mrc-1-000278           청구취지는 밝히는 방법은?
# 528  mrc-0-000030     수사들이 전쟁의 대가로 지은 건물은?
# 538  mrc-0-004085        맥국이라는 명칭을 알린 사람은?
# 583  mrc-0-001659  인간에게 불타는 느낌의 아픔을 주는 것은?
#
#                                                                                                                                    predictions  \
# 7                                                                     [무명, 호조 마사코, 인격적 존재, 시공을 초월한 영원한 존재, 지질, 선종 조사 초상에 연고를 두고 있기 때문, 유루(有漏)]
# 150      [대지의 여신 가이아, 카를 마르텔, 가이아, 타르타로스, 제우스, 제우스가 크로노스를 물리치고 신들의 지배자 자리에 오르자 이에 분노하여 크로노스의 원수를 갚기 위해 그녀의 또 다른 배우자인 타르타로스, 프랑스 귀족 생시몽 공작 클로드]
# 256                                                        [바이스, <고골에게 보내는 편지>, 벨린스키의 <고골에게 보내는 편지>, <마라의 박해와 암살>, ≪악령≫, 격언시, 싱글 Shipbuilding]
# 300                                                                                    [식중독, 헬리콥터 추락사고, 중풍, 독살, 요로감염증, 중풍과 등창, 노환 등의 합병증, 합병증]
# 460  [이즈마 하치로로, '주즈 알-나시샤바', ≪바람 속에서 벌거벗고(Naked in the Wind)≫, 마하프라즈냐파라미타샤스트라(Mahaprajnaparamita­sastra), Mustang (야생마), 마하프라즈냐파라미타샤스트라, 코우테츠]
# 472                                                                                    ['청구의 원인', '청구의 원인' 기재, 정보공개, 충분한 시간, 소송, 구술, 사전 구속 영장]
# 528                                                                                        [충무사(忠武祠), 평창향교, 크로메르지시궁, 아타우알파, 임진왜란, 영천 숭렬당, 충무사]
# 538                                                                          [실학자들, 표트르 1세, 제임스 맥헨리, 지바 쿤다(Ziva Kunda), R. J. 셰퍼, 프랭크 맥린, 실학자]
# 583                                                                                                  [유산, 위대한 유토피아, 세계, 이중예정론, 백루검, 바위, 솔레놉신이]
#
#      difficulty
# 7             1
# 150           1
# 256           1
# 300           1
# 460           1
# 472           1
# 528           1
# 538           1
# 583           1

# %%
df[df["difficulty"] == 2]
# Out:
#                id                                             question  \
# 0    mrc-1-000653                                유령'은 어느 행성에서 지구로 왔는가?
# 16   mrc-0-000266                               통대를 뽑을 수 있었던 주체는 누구인가?
# 57   mrc-0-003763                                  불상에 대한 정보가 적혀있는 것은?
# 74   mrc-0-004430                어머니를 죽음에 이르게 한 것은 아들이 무엇처럼 행동했기 때문인가?
# 85   mrc-1-000813                            태풍 초이완의 경보는 어떤 순간부터 풀렸는가?
# 134  mrc-0-001034                           공소권이 사라질 경우 무엇에서 벗어나게 되는가?
# 155  mrc-0-001884                             레빌 장군은 무엇이 없었기 때문에 실망했나?
# 166  mrc-0-003205                      석조지장보살상이 조각되지 않았을 것으로 추정되는 시기는?
# 214  mrc-1-000256  본인의 일에 진중하게 임했고 많은 것을 연습했지만, 자신의 옷차림에 불만을 제기했던 인물은?
# 263  mrc-1-001797                                        이경언이 사망한 장소는?
# 295  mrc-0-001961                                      낮에는 어떤 바람이 부는가?
# 329  mrc-0-001847                         자신의 사리사욕만 채우며 무능했던 진나라의 황제는?
# 333  mrc-0-001757                             Yoo Doo Right이 수록된 앨범명은?
# 354  mrc-0-002074                                       야전의 전투 제한 시간은?
# 369  mrc-0-001415                                  이무훈에게 살해당한 인물의 직책은?
# 381  mrc-0-002033             신문 <파시스트 정권,Il Regime Fascista>의 주된 논조는?
# 400  mrc-0-002618                                       무관학교를 설립한 인물은?
# 407  mrc-0-003639                                       단어 '토레혼'의 어근은?
# 434  mrc-1-000218                        레이크가 가장 큰 영향을 받았다고 한 작품의 이름은?
# 436  mrc-1-000690                         레이가 골트 이후에 사용한 가짜 이름은 무엇인가요?
# 466  mrc-0-000527                                 조선박물연구회가 공포하고자 한 것은?
# 468  mrc-0-001931                           스탈린그라드의 소련군 중 사정이 나았던 부대는?
# 477  mrc-0-004371                                역할을 가장 먼저 구체화 시킨 사람은?
# 486  mrc-1-000651                      대한민국 보물 제 1540호를 보관하는 장소는 어디인가?
# 513  mrc-0-002696                                  베이핑-톈진 전투가 시작된 연도는?
# 516  mrc-1-000972                               연방군의 레이다를 무력화시킨 화학무기는?
# 530  mrc-0-000162                               최재수는 2012년에 어디로 이적했는가?
# 540  mrc-0-003441             에스토니아는 희망을 가졌는가' 를 발표한 인물이 리투아니와 협력한 떄는?
# 558  mrc-1-001426                                   한국이 무시한 일본 측의 주장은?
# 584  mrc-0-002991                  처음에는 후짱을 반대했지만 마지막에 후짱의 도움을 받은 인물은?
#
#                                                                                                                             predictions  \
# 0                                                                           [우스, 사만 행성, 사만, 베텔게우스(Betelgeuse) 근처의 작은 행성, 지구, 사만, 사만 행성]
# 16                                                                                        [국민, 데르브포르갈, 학교, 충분한 시간, 앙리 브리송 행정부, 하느님, 국민]
# 57                                                                        [묘법연화경, 광배(光背)의 뒷면, 중수 발원문, 광배(光背)의 뒷면, 조성발원기에, 중수 발원문, 복장유물]
# 74                                                                 [길거리 불한당, 자신의 감정을 드러내보인 적이 없었기 때문, 교육 평론가, 제우스, 정신이상자, 골수암, 길거리 불한당]
# 85                                                                 [9월 16일 오후, 5월 18일, 9월 14일, 9월 16일 오후, 9월 13일, 9월 13일, 10월 10일 21시경]
# 134                                                    ['죄를 범한 자', 폭행, 피고인, 검찰의 공소 유지에 의한 명백한 한계, 피고인, 흉기를 사용하며 협박한 부분이 무혐의, '죄를 범한 자']
# 155                                                   [전차포와 부무장을 '인간형'의 상반신, '인간형'의 상반신, 복잡한 2족 보행기구, 복잡한 2족 보행기구, 유효한 요격 방법, 하반신, 하반신]
# 166                                                                                   [조선후기에, 17세기, 17세기, 조선후기에, 18세기 전반, 조선 초기, 1646년]
# 214                                                                                           [매소드, 대마녀, 를르네 지카르트, 이재현, 쿠니스, 마튀랭이, 쿠니스]
# 263                                                                                  [감옥, 청주, 청주, 서구 감천동 뒷산, 미얀마 아웅산 묘역, 서구 감천동 뒷산, 감옥]
# 295                                                                       [동남풍, 남서풍, 열대 계절풍(몬순), 따뜻하고 건조한 바람, 저지로부터 올라 오는 바람, 북동풍, 동남풍]
# 329                                                                      [2세 황제 호해, 유스티니아누스 1세, 진시황, 2세 황제 호해, 진 시황제, 유스티니아누스 1세, 이세황제]
# 333  [Delay 1968, 《私このままでいいのかな》(나 이대로 괜찮을까), So Wrong, It's Right, 《Beatles for Sale》, 《私このままでいいのかな》(나 이대로 괜찮을까), 《십만개위십마》, Delay 1968]
# 354                                                                              [최대 10일, 밤, 밤, 북한군의 진격을 지연시키기 위한 전투, 태릉전투, 5턴, 최대 10일]
# 369                                                                         [시인, 총무주석간사, 중의원 의원, 노룡군의 대장, 성문교위(城門校尉), 양복점의 직공, 노룡군의 대장]
# 381                                                                              [급진파 파시스트, 급진파, 급진파, 급진파 파시스트, 정치평론면, 정치평론면, 반(反)파시스트]
# 400                                                                                         [태황제, 조진태, 기호흥학회, 기호흥학회, 오가와 오사무, 이항직, 태황제]
# 407                   [토레, '온' (ón)은 엄청난 크기나 높이를 강조할 때 흔히 붙이는 접미사다. 따라서 '토레혼 (torrejón)'이라는 말은 '거대한 탑', 탑, '거대한 탑', '온' (ón), '온', '온']
# 434                                       [《나뭇잎의 집》, 보러블 3부작, <The Romaunt of Rose>, ≪나체즈 족≫, <The Romaunt of Rose>, 보러블 3부작, 《나뭇잎의 집》]
# 436                                                                   [리카르도 클레멘트, 츠와몬, 드미트리 1세, 드미트리 1세, "에릭 스타보 골트", 츠와몬, '리카르도 클레멘트']
# 466                                                                     [국보 제151호, 보물, 남원 양대박 부자충의문, 남원 양대박 부자충의문, 과학, 수문장계회도, 과학의 중요성]
# 468                                                                              [제4기갑군, 64 군, 프리드리히 파울루스의 독일군, 제6군, 제6군, 독일 제6군, 제 6군]
# 477                                                                 [신돈, 미드(Mead), 리처드 파인먼, 본문\n본문(body), 미드(Mead), 나카지마 타츠오, 블라디미르 레닌]
# 486                                                [호림박물관, <고려대 도서관>, 동·서 사간판전(寺刊版殿), 서울시 종로구 종로4가 동원예식장 뒤뜰, 국립춘천박물관, <고려대 도서관>, 호림박물관]
# 513                                                                                   [1947년, 1948년, 1946년, 1949년, 1948년, 1946년, 1942년]
# 516                          [미노프스키 입자 산포, 염소가스, '오딘(ODIN - Orbital Defense Initiative, 궤도 방어 무기)', 「솔라 시스템」, 미노프스키 입자, 염소가스, 미노프스키 입자]
# 530                                                               [ASD 토레스 칼초, 레딩, 레딩, 1. FFC 투르비네 포츠담, 튀레쇠 FF, 스타베크 포트발 크빈네르, AEK 아테네]
# 540                            [에스토니아 인민전선, 에스토니아 인민전선의 창립위원으로서 라트비아와 리투아니아 인민전선, 에스토니아 인민전선의 창립위원으로서 라트비아, 에스토니아 인민전선, 인민전선, 외셀, 인민전선]
# 558                                                                       [독도 주변수역, 독도 영유권, 독도 영유권, 중재위원회를 설치, "수출 규제 해제 요청", 독도, 직선기선]
# 584                                                                   [호시노 청년, 아유미, 스마일과 스위트 멤버들이, 스마일과 스위트 멤버들이, 아유미, 사카가미 아유미, 응오시리엔]
#
#      difficulty
# 0             2
# 16            2
# 57            2
# 74            2
# 85            2
# 134           2
# 155           2
# 166           2
# 214           2
# 263           2
# 295           2
# 329           2
# 333           2
# 354           2
# 369           2
# 381           2
# 400           2
# 407           2
# 434           2
# 436           2
# 466           2
# 468           2
# 477           2
# 486           2
# 513           2
# 516           2
# 530           2
# 540           2
# 558           2
# 584           2

# %% [markdown]
# ## 가설
# 1. 여러 모델이 똑같이 답변한 예측은 정답일 확률이 높고, 답이 갈리면 오답일 확률이 높을 것이다.
# 2. 여러 모델이 똑같이 답변한 예측은 난이도가 쉬운 편일 것이고, 답이 갈리면 난이도가 높을 것이다.
# 3. 모든 모델이 다 틀리는 경우는 거의 없을 것이다. 적어도 하나의 모델은 정답을 예측했을 것이다.
# 4. 난이도를 분류할 수 있고, 쉬운 문제만 잘 푸는 모델과 어려운 문제만 잘 푸는 모델이 존재한다면 계층적으로 앙상블을 적용할 수 있을 것이다.

# %% [markdown]
# ## 궁금증
# 1. 쉬운 문제만 잘 푸는 모델이 있지 않을까?
# 2. 쉬운 문제를 틀리면서 어려운 문제 잘 맞추는 모델이 존재할 수 있을까? 혹은 어려운 문제를 잘 풀면 쉬운 문제도 잘 풀지 않을까?

# %% [markdown]
# # 최상위 두 예측 비교

# %%
import json


def merge_and_split_json(file1_path, file2_path, same_output_path, diff_output_path):
    # 두 JSON 파일 읽기
    with open(file1_path, "r", encoding="utf-8") as f1, open(
        file2_path, "r", encoding="utf-8"
    ) as f2:
        data1 = json.load(f1)
        data2 = json.load(f2)

    same_values = {}
    diff_values = {}

    # 모든 키에 대해 반복
    all_keys = set(data1.keys()) | set(data2.keys())
    for key in all_keys:
        value1 = data1.get(key)
        value2 = data2.get(key)

        if value1 == value2:
            # 값이 같은 경우
            same_values[key] = value1
        else:
            # 값이 다른 경우
            diff_values[key] = [value1, value2]

    # 결과를 JSON 파일로 저장
    with open(same_output_path, "w", encoding="utf-8") as f_same:
        json.dump(same_values, f_same, ensure_ascii=False, indent=2)

    with open(diff_output_path, "w", encoding="utf-8") as f_diff:
        json.dump(diff_values, f_diff, ensure_ascii=False, indent=2)

    print(f"같은 값을 가진 항목들은 {same_output_path}에 저장되었습니다.")
    print(f"다른 값을 가진 항목들은 {diff_output_path}에 저장되었습니다.")


# 사용 예시
file1_path = "data/output1.json"
file2_path = "data/output2.json"
same_output_path = "data/same_values.json"
diff_output_path = "data/diff_values.json"

merge_and_split_json(file1_path, file2_path, same_output_path, diff_output_path)
# Out:
# 같은 값을 가진 항목들은 data/same_values.json에 저장되었습니다.
# 다른 값을 가진 항목들은 data/diff_values.json에 저장되었습니다.

# %%
with open(diff_output_path, "r", encoding="utf-8") as f:
    data = json.load(f)

print(len(data))

df = pd.read_csv("data/test_validation_dataset.csv")
df["predictions"] = df["id"].map(data)
df = df.dropna()
df = df[["id", "question", "predictions"]]
# Out:
# 32

# %%
pd.set_option("display.max_rows", 32)
df
# Out:
#                id                                        question  \
# 27   mrc-0-001206                                펌프가 발매된 해는 언제인가?
# 30   mrc-0-003133               아델리 펭귄의 목숨에 지장을 주는 사람의 업종은 무엇인가요?
# 93   mrc-0-003670                      최고령 초등학생으로 기네스북에 올라있는 사람은?
# 129  mrc-0-001241               협동 화폐 거래소의 인정은 어느 부문에서 나타나는 변화인가?
# 150  mrc-1-000116                                  튀폰의 아버지는 누구인가?
# 162  mrc-0-004626                            장정기가 들어있는 우산이끼의 가지는?
# 172  mrc-0-003614                           호르몬의 주요 생성장소가 위치한 곳은?
# 186  mrc-0-004460                    주인규는 무엇 때문에 스스로 생을 마감하게 되는가?
# 259  mrc-0-001220   양산이씨 종가가 보유한 왕지 중 양산이씨의 시조와 관련한 왕지는 몇 점이 있는가?
# 280  mrc-0-004738                         주권재민의 원칙은 어디에 명시되어 있는가?
# 288  mrc-0-000288                      도스토옙스키를 연구할 때 큰 도움이 됐던 책은?
# 300  mrc-0-004196                            루이가 사망하게 될 원인은 무엇인가?
# 308  mrc-0-002848          퀵실버(영화)에서 집시를 고가도로에서 추락시킨 사람을 연기한 배우는?
# 310  mrc-1-000267                           도쇼구 역의 승강장은 몇 층에 있는가?
# 324  mrc-0-003514                 함세환은 어느 군대에 스스로 입대하여 전투에 참여했나요?
# 334  mrc-0-001778                               고스자쿠 천황이 사망한 연도는?
# 381  mrc-0-002033        신문 <파시스트 정권,Il Regime Fascista>의 주된 논조는?
# 385  mrc-0-004245            이토 히로부미가 정치적 대립관계인 오쿠마 시게노부에게 준 관직은?
# 388  mrc-1-001394     중세 아랍 제국에서 여권과 세금 납부 증명서를 겸용한 서류의 이름은 무엇인가?
# 407  mrc-0-003639                                  단어 '토레혼'의 어근은?
# 423  mrc-1-001071        좌운검이 도연이 정조의 자손인 것을 아무도 모르게 하기 위해 한 행동은?
# 431  mrc-1-001269                              에이몬 b. 킹을 파견한 사람은?
# 436  mrc-1-000690                    레이가 골트 이후에 사용한 가짜 이름은 무엇인가요?
# 441  mrc-0-005410  쓰루가 방면의 신쾌속 열차가 특급 선더버드 호의 추월을 위해 대기할 때는 언제인가?
# 442  mrc-0-004579                     경서교회를 설립한 사람이 태어난 도시는 어디인가?
# 466  mrc-0-000527                            조선박물연구회가 공포하고자 한 것은?
# 472  mrc-1-000278                                  청구취지는 밝히는 방법은?
# 487  mrc-0-004649                    히틀러의 권한을 합법적으로 확대시켜준 국가 기관은?
# 516  mrc-1-000972                          연방군의 레이다를 무력화시킨 화학무기는?
# 530  mrc-0-000162                          최재수는 2012년에 어디로 이적했는가?
# 536  mrc-0-001878                속리산에서 임경업 장군의 설화가 깃들어있는 곳은 어디인가?
# 584  mrc-0-002991             처음에는 후짱을 반대했지만 마지막에 후짱의 도움을 받은 인물은?
#
#                              predictions
# 27                        [2004년, 2007년]
# 30                            [책, 불법 어업]
# 93                     [퍼스트 그레이더, ‘마루게’]
# 129                       [환율 부문, 상업 분야]
# 150                  [대지의 여신 가이아, 타르타로스]
# 162                      [웅기탁(수그루), 웅기탁]
# 172                          [복벽 내, 생식샘]
# 186                          [고문, 말기 폐암]
# 259                             [4점, 1점]
# 280                          [헌법, 일본국헌법]
# 288                   [『훈민정음』, 《작가의 일기》]
# 300                           [식중독, 합병증]
# 308                   [케빈 베이컨 분, 케빈 베이컨]
# 310                             [2층, 3층]
# 324                       [붉은 군대, 인민의용군]
# 334                       [1953년, 1045년]
# 381                      [급진파 파시스트, 급진파]
# 385                  [외무대신, 외무대신과 농상무대신]
# 388                          [바라아, 바라아가]
# 407                       ['온', '거대한 탑']
# 423       [남자아이 빈, 남자아이 빈을 데려다 양자로 삼는다.]
# 431                      [제임스 패닌 대령, 패닌]
# 436                   [츠와몬, '리카르도 클레멘트']
# 441  [오미이마즈 역에서 병결 및 분리를 하는 동안, 오미이마즈 역]
# 442                [루이지애나주 센터빌, 전라북도 전주]
# 466              [남원 양대박 부자충의문, 과학의 중요성]
# 472                 ['청구의 원인', 사전 구속 영장]
# 487                          [내각, 에피타시아]
# 516                  [염소가스, 미노프스키 입자 산포]
# 530                  [레딩, 스타베크 포트발 크빈네르]
# 536                      [문장대, 입석대(立石臺)]
# 584                 [아유미, 스마일과 스위트 멤버들이]

# %% [markdown]
# ### 질문과 답변의 유사성, 그리고 답변간의 유사성을 통해 Retriever가 틀린 Context를 가져왔는지 여부와 두 모델이 동일한 Context를 참고했는지 등을 추정할 수 있다.
# - 예를 들어 `도스토옙스키를 연구할 때 큰 도움이 됐던 책은?` -> `[『훈민정음』, 《작가의 일기》]`는 이는 서로 다른 문서에서 정답을 가져왔을 것이다.
# - `주권재민의 원칙은 어디에 명시되어 있는가?` -> `[헌법, 일본국헌법]`는 같은 문서지만 Reader가 서로 다른 정답을 추정한 것이다.
